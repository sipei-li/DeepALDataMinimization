# %%
import numpy as np
import pandas as pd
import tensorflow as tf 
import scipy.sparse as sp
from recommenders.evaluation.python_evaluation import (
    map_at_k,
    ndcg_at_k,
    precision_at_k,
    recall_at_k,
)

import MLP
from utils import get_top_k_scored_items, nCoreReduction, user_fixed_train_test_split

import matplotlib.pyplot as plt 

import importlib 

import ActiveLearner

# disable the SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Load data

# %%
data_path = "./data/ml-100k/u.data"
data_columns = ['user_id', 'item_id', 'rating', 'timestamp']

user_path = "./data/ml-100k/u.user"
user_columns = ['user_id', 'age', 'gender', 'occupation', 'zip_code']

# %%
data_df = pd.read_csv(data_path, sep='\t', names=data_columns, header=None)
user_df = pd.read_csv(user_path, sep='|', names=user_columns, header=None)

# %%
# shuffle data_df
data_df = data_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Convert to implicit feedback
#
# **Note**: For MovieLens 100k dataset, we are converting a rating in the range [1, 5] to an implicit feedback of 1 so that we still have a significant number of positive samples in the dataset. For MovieLens 1M, we could do [3, 5] instead.
#
# We might not need this.

# %%
data_df['rating'] = (data_df['rating'] >= 1).astype(int)

# %% [markdown]
# ## Dimensionality reduction
#
# Only keep:
# - users that provided at least 5 ratings
# - items that received at least 5 ratings

# %%
ncore_data_df = nCoreReduction(data_df)

# %%
print(f"The original data frame shape: {data_df.shape}")
print(f"  - # users: {data_df['user_id'].nunique()}")
print(f"  - # items: {data_df['item_id'].nunique()}")
print('\n')

print(f"The filtered data frame shape: {ncore_data_df.shape}")
print(f"  - # users: {ncore_data_df['user_id'].nunique()}")
print(f"  - # items: {ncore_data_df['item_id'].nunique()}")
# Out:
# The original data frame shape: (100000, 4)
#   - # users: 943
#   - # items: 1682
#
#
# The filtered data frame shape: (99032, 4)
#   - # users: 943
#   - # items: 1298

# %% [markdown]
# ## Convert id to inner id

# %%
unique_users = ncore_data_df['user_id'].unique()
user_id_to_iid = {id: iid for iid, id in enumerate(unique_users)}
user_iid_to_id = {iid: id for iid, id in enumerate(unique_users)}

unique_items = ncore_data_df['item_id'].unique()
item_id_to_iid = {id: iid for iid, id in enumerate(unique_items)}
item_iid_to_id = {iid: id for iid, id in enumerate(unique_items)}

# %%
n_users = unique_users.shape[0]
n_items = unique_items.shape[0]

# %%
ncore_data_df['user_iid'] = ncore_data_df['user_id'].map(user_id_to_iid)
ncore_data_df['item_iid'] = ncore_data_df['item_id'].map(item_id_to_iid)

# apply to `user_df`` as well
user_df['user_iid'] = user_df['user_id'].map(user_id_to_iid)

# %%
iid_to_gender = dict(zip(user_df['user_iid'], user_df['gender']))

# %%
n_female, n_male = user_df['gender'].value_counts()[['F', 'M']]
print(f"Number of female users: {n_female}")
print(f"Number of male users: {n_male}")
# Out:
# Number of female users: 273
# Number of male users: 670

# %%
nratings_female = ncore_data_df[ncore_data_df['user_iid'].map(iid_to_gender) == 'F']
nratings_male = ncore_data_df[ncore_data_df['user_iid'].map(iid_to_gender) == 'M']
print(f"Number of ratings for female users: {nratings_female.shape[0]}")
print(f"Number of ratings for male users: {nratings_male.shape[0]}")
print(f"Percentage of ratings from female users: {100 * nratings_female.shape[0] / ncore_data_df.shape[0]:.2f}")
# Out:
# Number of ratings for female users: 25385
# Number of ratings for male users: 73647
# Percentage of ratings from female users: 25.63

# %% [markdown]
# ## Train test split (user-fixed)

# %%
train_df, test_df = user_fixed_train_test_split(ncore_data_df, test_size=0.3, random_state=42)

# %% [markdown]
# ## Personalized Active Learning

# %%
# hyper-parameters

# hyper-parameter for rec sys
hparams = {
    'model_type': "neumf",
    'epochs': 50,
    'learning_rate': 0.01,
    'batch_size': 1024,
    'n_factors': 32,
    'layer_sizes': [32, 16, 8],
    'top_k': 10,
    'verbose': 10,
}


n_iters = 5   # number of repeated experiments
n_epochs = 26 # epoch of active learning process
q = 50        # active learning query list size

# %%
MaxRating_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.RatingBasedActiveLearner(
        strategy = 'MaxRating', 
        model = MLP.NCF,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=q,
        seed=iter,
        ratio=None,
    )
    MaxRating_results_lst.append([])
    for epoch in range(n_epochs):
        print('------------------------------------')
        print(f'Epoch: {epoch+1}')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        MaxRating_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 10: Loss = 0.3494
# Epoch 20: Loss = 0.1674
# Epoch 30: Loss = 0.0574
# Epoch 40: Loss = 0.0264
# Epoch 50: Loss = 0.0166
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 9986
# Percentage of ratings elicited: 14.49%
# Epoch 10: Loss = 0.2017
# Epoch 20: Loss = 0.0715
# Epoch 30: Loss = 0.0379
# Epoch 40: Loss = 0.0348
# Epoch 50: Loss = 0.0267
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 17612
# Percentage of ratings elicited: 25.56%
# Epoch 10: Loss = 0.1256
# Epoch 20: Loss = 0.0689
# Epoch 30: Loss = 0.0555
# Epoch 40: Loss = 0.0437
# Epoch 50: Loss = 0.0382
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 25693
# Percentage of ratings elicited: 37.29%
# Epoch 10: Loss = 0.1225
# Epoch 20: Loss = 0.0806
# Epoch 30: Loss = 0.0667
# Epoch 40: Loss = 0.0554
# Epoch 50: Loss = 0.0509
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 32882
# Percentage of ratings elicited: 47.72%
# Epoch 10: Loss = 0.1291
# Epoch 20: Loss = 0.0932
# Epoch 30: Loss = 0.0795
# Epoch 40: Loss = 0.0678
# Epoch 50: Loss = 0.0641
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 39178
# Percentage of ratings elicited: 56.86%
# Epoch 10: Loss = 0.1307
# Epoch 20: Loss = 0.0991
# Epoch 30: Loss = 0.0887
# Epoch 40: Loss = 0.0758
# Epoch 50: Loss = 0.0713
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 44445
# Percentage of ratings elicited: 64.51%
# Epoch 10: Loss = 0.1355
# Epoch 20: Loss = 0.1085
# Epoch 30: Loss = 0.0951
# Epoch 40: Loss = 0.0881
# Epoch 50: Loss = 0.0829
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 48668
# Percentage of ratings elicited: 70.63%
# Epoch 10: Loss = 0.1441
# Epoch 20: Loss = 0.1161
# Epoch 30: Loss = 0.1053
# Epoch 40: Loss = 0.0935
# Epoch 50: Loss = 0.0892
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52117
# Percentage of ratings elicited: 75.64%
# Epoch 10: Loss = 0.1515
# Epoch 20: Loss = 0.1190
# Epoch 30: Loss = 0.1081
# Epoch 40: Loss = 0.1019
# Epoch 50: Loss = 0.0953
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54828
# Percentage of ratings elicited: 79.58%
# Epoch 10: Loss = 0.1551
# Epoch 20: Loss = 0.1296
# Epoch 30: Loss = 0.1170
# Epoch 40: Loss = 0.1075
# Epoch 50: Loss = 0.1001
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 57009
# Percentage of ratings elicited: 82.74%
# Epoch 10: Loss = 0.1625
# Epoch 20: Loss = 0.1313
# Epoch 30: Loss = 0.1185
# Epoch 40: Loss = 0.1097
# Epoch 50: Loss = 0.1051
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58668
# Percentage of ratings elicited: 85.15%
# Epoch 10: Loss = 0.1672
# Epoch 20: Loss = 0.1400
# Epoch 30: Loss = 0.1260
# Epoch 40: Loss = 0.1159
# Epoch 50: Loss = 0.1103
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 60011
# Percentage of ratings elicited: 87.10%
# Epoch 10: Loss = 0.1705
# Epoch 20: Loss = 0.1412
# Epoch 30: Loss = 0.1287
# Epoch 40: Loss = 0.1199
# Epoch 50: Loss = 0.1125
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61131
# Percentage of ratings elicited: 88.72%
# Epoch 10: Loss = 0.1730
# Epoch 20: Loss = 0.1449
# Epoch 30: Loss = 0.1311
# Epoch 40: Loss = 0.1259
# Epoch 50: Loss = 0.1191
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62067
# Percentage of ratings elicited: 90.08%
# Epoch 10: Loss = 0.1780
# Epoch 20: Loss = 0.1513
# Epoch 30: Loss = 0.1345
# Epoch 40: Loss = 0.1266
# Epoch 50: Loss = 0.1217
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 62772
# Percentage of ratings elicited: 91.10%
# Epoch 10: Loss = 0.1777
# Epoch 20: Loss = 0.1534
# Epoch 30: Loss = 0.1359
# Epoch 40: Loss = 0.1307
# Epoch 50: Loss = 0.1247
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63253
# Percentage of ratings elicited: 91.80%
# Epoch 10: Loss = 0.1817
# Epoch 20: Loss = 0.1530
# Epoch 30: Loss = 0.1385
# Epoch 40: Loss = 0.1305
# Epoch 50: Loss = 0.1233
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 63708
# Percentage of ratings elicited: 92.46%
# Epoch 10: Loss = 0.1837
# Epoch 20: Loss = 0.1562
# Epoch 30: Loss = 0.1395
# Epoch 40: Loss = 0.1351
# Epoch 50: Loss = 0.1251
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 64165
# Percentage of ratings elicited: 93.13%
# Epoch 10: Loss = 0.1839
# Epoch 20: Loss = 0.1555
# Epoch 30: Loss = 0.1446
# Epoch 40: Loss = 0.1342
# Epoch 50: Loss = 0.1241
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 64743
# Percentage of ratings elicited: 93.97%
# Epoch 10: Loss = 0.1848
# Epoch 20: Loss = 0.1600
# Epoch 30: Loss = 0.1426
# Epoch 40: Loss = 0.1342
# Epoch 50: Loss = 0.1238
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 65517
# Percentage of ratings elicited: 95.09%
# Epoch 10: Loss = 0.1899
# Epoch 20: Loss = 0.1572
# Epoch 30: Loss = 0.1470
# Epoch 40: Loss = 0.1323
# Epoch 50: Loss = 0.1278
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 66147
# Percentage of ratings elicited: 96.00%
# Epoch 10: Loss = 0.1924
# Epoch 20: Loss = 0.1599
# Epoch 30: Loss = 0.1448
# Epoch 40: Loss = 0.1365
# Epoch 50: Loss = 0.1272
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 66884
# Percentage of ratings elicited: 97.07%
# Epoch 10: Loss = 0.1887
# Epoch 20: Loss = 0.1620
# Epoch 30: Loss = 0.1489
# Epoch 40: Loss = 0.1370
# Epoch 50: Loss = 0.1274
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67471
# Percentage of ratings elicited: 97.92%
# Epoch 10: Loss = 0.1896
# Epoch 20: Loss = 0.1604
# Epoch 30: Loss = 0.1476
# Epoch 40: Loss = 0.1366
# Epoch 50: Loss = 0.1279
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68040
# Percentage of ratings elicited: 98.75%
# Epoch 10: Loss = 0.1946
# Epoch 20: Loss = 0.1635
# Epoch 30: Loss = 0.1516
# Epoch 40: Loss = 0.1382
# Epoch 50: Loss = 0.1298
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68592
# Percentage of ratings elicited: 99.55%
# Epoch 10: Loss = 0.1955
# Epoch 20: Loss = 0.1648
# Epoch 30: Loss = 0.1511
# Epoch 40: Loss = 0.1412
# Epoch 50: Loss = 0.1281
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 2
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 10: Loss = 0.3703
# Epoch 20: Loss = 0.1583
# Epoch 30: Loss = 0.0730
# Epoch 40: Loss = 0.0323
# Epoch 50: Loss = 0.0189
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 9555
# Percentage of ratings elicited: 13.87%
# Epoch 10: Loss = 0.1989
# Epoch 20: Loss = 0.0676
# Epoch 30: Loss = 0.0404
# Epoch 40: Loss = 0.0279
# Epoch 50: Loss = 0.0209
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 16856
# Percentage of ratings elicited: 24.46%
# Epoch 10: Loss = 0.1341
# Epoch 20: Loss = 0.0708
# Epoch 30: Loss = 0.0524
# Epoch 40: Loss = 0.0406
# Epoch 50: Loss = 0.0387
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 24771
# Percentage of ratings elicited: 35.95%
# Epoch 10: Loss = 0.1265
# Epoch 20: Loss = 0.0795
# Epoch 30: Loss = 0.0679
# Epoch 40: Loss = 0.0556
# Epoch 50: Loss = 0.0526
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 32321
# Percentage of ratings elicited: 46.91%
# Epoch 10: Loss = 0.1298
# Epoch 20: Loss = 0.0919
# Epoch 30: Loss = 0.0761
# Epoch 40: Loss = 0.0667
# Epoch 50: Loss = 0.0640
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 38869
# Percentage of ratings elicited: 56.41%
# Epoch 10: Loss = 0.1384
# Epoch 20: Loss = 0.1024
# Epoch 30: Loss = 0.0892
# Epoch 40: Loss = 0.0795
# Epoch 50: Loss = 0.0728
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 44263
# Percentage of ratings elicited: 64.24%
# Epoch 10: Loss = 0.1433
# Epoch 20: Loss = 0.1081
# Epoch 30: Loss = 0.0991
# Epoch 40: Loss = 0.0887
# Epoch 50: Loss = 0.0836
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 48468
# Percentage of ratings elicited: 70.34%
# Epoch 10: Loss = 0.1452
# Epoch 20: Loss = 0.1166
# Epoch 30: Loss = 0.1052
# Epoch 40: Loss = 0.0936
# Epoch 50: Loss = 0.0904
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 51826
# Percentage of ratings elicited: 75.22%
# Epoch 10: Loss = 0.1519
# Epoch 20: Loss = 0.1215
# Epoch 30: Loss = 0.1079
# Epoch 40: Loss = 0.1013
# Epoch 50: Loss = 0.0947
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54487
# Percentage of ratings elicited: 79.08%
# Epoch 10: Loss = 0.1554
# Epoch 20: Loss = 0.1280
# Epoch 30: Loss = 0.1176
# Epoch 40: Loss = 0.1088
# Epoch 50: Loss = 0.1034
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56610
# Percentage of ratings elicited: 82.16%
# Epoch 10: Loss = 0.1599
# Epoch 20: Loss = 0.1336
# Epoch 30: Loss = 0.1253
# Epoch 40: Loss = 0.1151
# Epoch 50: Loss = 0.1053
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58281
# Percentage of ratings elicited: 84.59%
# Epoch 10: Loss = 0.1634
# Epoch 20: Loss = 0.1366
# Epoch 30: Loss = 0.1258
# Epoch 40: Loss = 0.1162
# Epoch 50: Loss = 0.1082
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59617
# Percentage of ratings elicited: 86.53%
# Epoch 10: Loss = 0.1688
# Epoch 20: Loss = 0.1404
# Epoch 30: Loss = 0.1303
# Epoch 40: Loss = 0.1216
# Epoch 50: Loss = 0.1112
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 60666
# Percentage of ratings elicited: 88.05%
# Epoch 10: Loss = 0.1727
# Epoch 20: Loss = 0.1460
# Epoch 30: Loss = 0.1333
# Epoch 40: Loss = 0.1275
# Epoch 50: Loss = 0.1187
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 61611
# Percentage of ratings elicited: 89.42%
# Epoch 10: Loss = 0.1766
# Epoch 20: Loss = 0.1474
# Epoch 30: Loss = 0.1352
# Epoch 40: Loss = 0.1251
# Epoch 50: Loss = 0.1190
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 62370
# Percentage of ratings elicited: 90.52%
# Epoch 10: Loss = 0.1794
# Epoch 20: Loss = 0.1477
# Epoch 30: Loss = 0.1363
# Epoch 40: Loss = 0.1282
# Epoch 50: Loss = 0.1189
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 62940
# Percentage of ratings elicited: 91.35%
# Epoch 10: Loss = 0.1825
# Epoch 20: Loss = 0.1522
# Epoch 30: Loss = 0.1396
# Epoch 40: Loss = 0.1306
# Epoch 50: Loss = 0.1234
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 63314
# Percentage of ratings elicited: 91.89%
# Epoch 10: Loss = 0.1855
# Epoch 20: Loss = 0.1529
# Epoch 30: Loss = 0.1406
# Epoch 40: Loss = 0.1306
# Epoch 50: Loss = 0.1235
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 63741
# Percentage of ratings elicited: 92.51%
# Epoch 10: Loss = 0.1851
# Epoch 20: Loss = 0.1562
# Epoch 30: Loss = 0.1409
# Epoch 40: Loss = 0.1330
# Epoch 50: Loss = 0.1254
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 64293
# Percentage of ratings elicited: 93.31%
# Epoch 10: Loss = 0.1860
# Epoch 20: Loss = 0.1572
# Epoch 30: Loss = 0.1438
# Epoch 40: Loss = 0.1333
# Epoch 50: Loss = 0.1255
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 65234
# Percentage of ratings elicited: 94.68%
# Epoch 10: Loss = 0.1904
# Epoch 20: Loss = 0.1619
# Epoch 30: Loss = 0.1442
# Epoch 40: Loss = 0.1370
# Epoch 50: Loss = 0.1284
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 66084
# Percentage of ratings elicited: 95.91%
# Epoch 10: Loss = 0.1915
# Epoch 20: Loss = 0.1627
# Epoch 30: Loss = 0.1472
# Epoch 40: Loss = 0.1397
# Epoch 50: Loss = 0.1298
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 66766
# Percentage of ratings elicited: 96.90%
# Epoch 10: Loss = 0.1927
# Epoch 20: Loss = 0.1651
# Epoch 30: Loss = 0.1463
# Epoch 40: Loss = 0.1369
# Epoch 50: Loss = 0.1283
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67554
# Percentage of ratings elicited: 98.05%
# Epoch 10: Loss = 0.1957
# Epoch 20: Loss = 0.1648
# Epoch 30: Loss = 0.1474
# Epoch 40: Loss = 0.1392
# Epoch 50: Loss = 0.1320
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68162
# Percentage of ratings elicited: 98.93%
# Epoch 10: Loss = 0.1962
# Epoch 20: Loss = 0.1673
# Epoch 30: Loss = 0.1529
# Epoch 40: Loss = 0.1420
# Epoch 50: Loss = 0.1315
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68635
# Percentage of ratings elicited: 99.61%
# Epoch 10: Loss = 0.1988
# Epoch 20: Loss = 0.1664
# Epoch 30: Loss = 0.1546
# Epoch 40: Loss = 0.1409
# Epoch 50: Loss = 0.1330
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 3
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 10: Loss = 0.3460
# Epoch 20: Loss = 0.1379
# Epoch 30: Loss = 0.0460
# Epoch 40: Loss = 0.0242
# Epoch 50: Loss = 0.0150
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 9978
# Percentage of ratings elicited: 14.48%
# Epoch 10: Loss = 0.1883
# Epoch 20: Loss = 0.0631
# Epoch 30: Loss = 0.0360
# Epoch 40: Loss = 0.0287
# Epoch 50: Loss = 0.0229
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 17766
# Percentage of ratings elicited: 25.78%
# Epoch 10: Loss = 0.1286
# Epoch 20: Loss = 0.0655
# Epoch 30: Loss = 0.0505
# Epoch 40: Loss = 0.0432
# Epoch 50: Loss = 0.0359
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 25644
# Percentage of ratings elicited: 37.22%
# Epoch 10: Loss = 0.1197
# Epoch 20: Loss = 0.0778
# Epoch 30: Loss = 0.0613
# Epoch 40: Loss = 0.0578
# Epoch 50: Loss = 0.0512
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 33016
# Percentage of ratings elicited: 47.92%
# Epoch 10: Loss = 0.1224
# Epoch 20: Loss = 0.0873
# Epoch 30: Loss = 0.0776
# Epoch 40: Loss = 0.0692
# Epoch 50: Loss = 0.0627
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 39384
# Percentage of ratings elicited: 57.16%
# Epoch 10: Loss = 0.1347
# Epoch 20: Loss = 0.0975
# Epoch 30: Loss = 0.0877
# Epoch 40: Loss = 0.0791
# Epoch 50: Loss = 0.0711
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 44737
# Percentage of ratings elicited: 64.93%
# Epoch 10: Loss = 0.1428
# Epoch 20: Loss = 0.1042
# Epoch 30: Loss = 0.0975
# Epoch 40: Loss = 0.0885
# Epoch 50: Loss = 0.0811
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 48867
# Percentage of ratings elicited: 70.92%
# Epoch 10: Loss = 0.1454
# Epoch 20: Loss = 0.1171
# Epoch 30: Loss = 0.1019
# Epoch 40: Loss = 0.0927
# Epoch 50: Loss = 0.0891
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52284
# Percentage of ratings elicited: 75.88%
# Epoch 10: Loss = 0.1513
# Epoch 20: Loss = 0.1229
# Epoch 30: Loss = 0.1096
# Epoch 40: Loss = 0.0996
# Epoch 50: Loss = 0.0963
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54950
# Percentage of ratings elicited: 79.75%
# Epoch 10: Loss = 0.1552
# Epoch 20: Loss = 0.1288
# Epoch 30: Loss = 0.1188
# Epoch 40: Loss = 0.1070
# Epoch 50: Loss = 0.0984
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 57158
# Percentage of ratings elicited: 82.96%
# Epoch 10: Loss = 0.1621
# Epoch 20: Loss = 0.1349
# Epoch 30: Loss = 0.1235
# Epoch 40: Loss = 0.1122
# Epoch 50: Loss = 0.1081
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58818
# Percentage of ratings elicited: 85.37%
# Epoch 10: Loss = 0.1664
# Epoch 20: Loss = 0.1419
# Epoch 30: Loss = 0.1264
# Epoch 40: Loss = 0.1186
# Epoch 50: Loss = 0.1109
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 60254
# Percentage of ratings elicited: 87.45%
# Epoch 10: Loss = 0.1710
# Epoch 20: Loss = 0.1436
# Epoch 30: Loss = 0.1330
# Epoch 40: Loss = 0.1215
# Epoch 50: Loss = 0.1141
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61402
# Percentage of ratings elicited: 89.12%
# Epoch 10: Loss = 0.1744
# Epoch 20: Loss = 0.1462
# Epoch 30: Loss = 0.1346
# Epoch 40: Loss = 0.1238
# Epoch 50: Loss = 0.1183
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62321
# Percentage of ratings elicited: 90.45%
# Epoch 10: Loss = 0.1810
# Epoch 20: Loss = 0.1465
# Epoch 30: Loss = 0.1364
# Epoch 40: Loss = 0.1291
# Epoch 50: Loss = 0.1209
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 63029
# Percentage of ratings elicited: 91.48%
# Epoch 10: Loss = 0.1812
# Epoch 20: Loss = 0.1545
# Epoch 30: Loss = 0.1402
# Epoch 40: Loss = 0.1309
# Epoch 50: Loss = 0.1231
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63545
# Percentage of ratings elicited: 92.23%
# Epoch 10: Loss = 0.1832
# Epoch 20: Loss = 0.1529
# Epoch 30: Loss = 0.1402
# Epoch 40: Loss = 0.1295
# Epoch 50: Loss = 0.1248
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 63948
# Percentage of ratings elicited: 92.81%
# Epoch 10: Loss = 0.1829
# Epoch 20: Loss = 0.1554
# Epoch 30: Loss = 0.1390
# Epoch 40: Loss = 0.1332
# Epoch 50: Loss = 0.1265
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 64297
# Percentage of ratings elicited: 93.32%
# Epoch 10: Loss = 0.1852
# Epoch 20: Loss = 0.1552
# Epoch 30: Loss = 0.1423
# Epoch 40: Loss = 0.1319
# Epoch 50: Loss = 0.1255
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 64854
# Percentage of ratings elicited: 94.13%
# Epoch 10: Loss = 0.1874
# Epoch 20: Loss = 0.1599
# Epoch 30: Loss = 0.1437
# Epoch 40: Loss = 0.1334
# Epoch 50: Loss = 0.1269
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 65582
# Percentage of ratings elicited: 95.18%
# Epoch 10: Loss = 0.1896
# Epoch 20: Loss = 0.1612
# Epoch 30: Loss = 0.1446
# Epoch 40: Loss = 0.1335
# Epoch 50: Loss = 0.1270
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 66234
# Percentage of ratings elicited: 96.13%
# Epoch 10: Loss = 0.1919
# Epoch 20: Loss = 0.1637
# Epoch 30: Loss = 0.1467
# Epoch 40: Loss = 0.1380
# Epoch 50: Loss = 0.1327
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 66925
# Percentage of ratings elicited: 97.13%
# Epoch 10: Loss = 0.1926
# Epoch 20: Loss = 0.1634
# Epoch 30: Loss = 0.1441
# Epoch 40: Loss = 0.1391
# Epoch 50: Loss = 0.1304
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67562
# Percentage of ratings elicited: 98.06%
# Epoch 10: Loss = 0.1946
# Epoch 20: Loss = 0.1657
# Epoch 30: Loss = 0.1494
# Epoch 40: Loss = 0.1407
# Epoch 50: Loss = 0.1327
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68134
# Percentage of ratings elicited: 98.89%
# Epoch 10: Loss = 0.1965
# Epoch 20: Loss = 0.1669
# Epoch 30: Loss = 0.1474
# Epoch 40: Loss = 0.1377
# Epoch 50: Loss = 0.1315
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68651
# Percentage of ratings elicited: 99.64%
# Epoch 10: Loss = 0.1970
# Epoch 20: Loss = 0.1670
# Epoch 30: Loss = 0.1530
# Epoch 40: Loss = 0.1418
# Epoch 50: Loss = 0.1362
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 4
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 10: Loss = 0.3687
# Epoch 20: Loss = 0.1425
# Epoch 30: Loss = 0.0534
# Epoch 40: Loss = 0.0251
# Epoch 50: Loss = 0.0145
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 10183
# Percentage of ratings elicited: 14.78%
# Epoch 10: Loss = 0.2020
# Epoch 20: Loss = 0.0692
# Epoch 30: Loss = 0.0411
# Epoch 40: Loss = 0.0317
# Epoch 50: Loss = 0.0265
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 17815
# Percentage of ratings elicited: 25.86%
# Epoch 10: Loss = 0.1241
# Epoch 20: Loss = 0.0680
# Epoch 30: Loss = 0.0529
# Epoch 40: Loss = 0.0448
# Epoch 50: Loss = 0.0371
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 25613
# Percentage of ratings elicited: 37.17%
# Epoch 10: Loss = 0.1239
# Epoch 20: Loss = 0.0830
# Epoch 30: Loss = 0.0674
# Epoch 40: Loss = 0.0536
# Epoch 50: Loss = 0.0510
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 33016
# Percentage of ratings elicited: 47.92%
# Epoch 10: Loss = 0.1290
# Epoch 20: Loss = 0.0915
# Epoch 30: Loss = 0.0733
# Epoch 40: Loss = 0.0689
# Epoch 50: Loss = 0.0660
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 39356
# Percentage of ratings elicited: 57.12%
# Epoch 10: Loss = 0.1304
# Epoch 20: Loss = 0.0996
# Epoch 30: Loss = 0.0847
# Epoch 40: Loss = 0.0781
# Epoch 50: Loss = 0.0753
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 44445
# Percentage of ratings elicited: 64.51%
# Epoch 10: Loss = 0.1381
# Epoch 20: Loss = 0.1092
# Epoch 30: Loss = 0.0921
# Epoch 40: Loss = 0.0872
# Epoch 50: Loss = 0.0833
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 48497
# Percentage of ratings elicited: 70.39%
# Epoch 10: Loss = 0.1485
# Epoch 20: Loss = 0.1171
# Epoch 30: Loss = 0.1058
# Epoch 40: Loss = 0.0932
# Epoch 50: Loss = 0.0887
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 51810
# Percentage of ratings elicited: 75.19%
# Epoch 10: Loss = 0.1510
# Epoch 20: Loss = 0.1217
# Epoch 30: Loss = 0.1109
# Epoch 40: Loss = 0.1013
# Epoch 50: Loss = 0.0935
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54498
# Percentage of ratings elicited: 79.10%
# Epoch 10: Loss = 0.1502
# Epoch 20: Loss = 0.1261
# Epoch 30: Loss = 0.1144
# Epoch 40: Loss = 0.1094
# Epoch 50: Loss = 0.0998
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56571
# Percentage of ratings elicited: 82.10%
# Epoch 10: Loss = 0.1602
# Epoch 20: Loss = 0.1349
# Epoch 30: Loss = 0.1219
# Epoch 40: Loss = 0.1105
# Epoch 50: Loss = 0.1069
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58320
# Percentage of ratings elicited: 84.64%
# Epoch 10: Loss = 0.1682
# Epoch 20: Loss = 0.1402
# Epoch 30: Loss = 0.1260
# Epoch 40: Loss = 0.1174
# Epoch 50: Loss = 0.1111
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59756
# Percentage of ratings elicited: 86.73%
# Epoch 10: Loss = 0.1716
# Epoch 20: Loss = 0.1431
# Epoch 30: Loss = 0.1291
# Epoch 40: Loss = 0.1214
# Epoch 50: Loss = 0.1168
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 60818
# Percentage of ratings elicited: 88.27%
# Epoch 10: Loss = 0.1711
# Epoch 20: Loss = 0.1460
# Epoch 30: Loss = 0.1349
# Epoch 40: Loss = 0.1230
# Epoch 50: Loss = 0.1160
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 61755
# Percentage of ratings elicited: 89.63%
# Epoch 10: Loss = 0.1765
# Epoch 20: Loss = 0.1462
# Epoch 30: Loss = 0.1352
# Epoch 40: Loss = 0.1269
# Epoch 50: Loss = 0.1220
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 62480
# Percentage of ratings elicited: 90.68%
# Epoch 10: Loss = 0.1779
# Epoch 20: Loss = 0.1522
# Epoch 30: Loss = 0.1367
# Epoch 40: Loss = 0.1284
# Epoch 50: Loss = 0.1236
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63051
# Percentage of ratings elicited: 91.51%
# Epoch 10: Loss = 0.1820
# Epoch 20: Loss = 0.1537
# Epoch 30: Loss = 0.1383
# Epoch 40: Loss = 0.1293
# Epoch 50: Loss = 0.1210
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 63535
# Percentage of ratings elicited: 92.21%
# Epoch 10: Loss = 0.1815
# Epoch 20: Loss = 0.1519
# Epoch 30: Loss = 0.1400
# Epoch 40: Loss = 0.1263
# Epoch 50: Loss = 0.1223
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 64057
# Percentage of ratings elicited: 92.97%
# Epoch 10: Loss = 0.1879
# Epoch 20: Loss = 0.1583
# Epoch 30: Loss = 0.1418
# Epoch 40: Loss = 0.1335
# Epoch 50: Loss = 0.1253
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 64726
# Percentage of ratings elicited: 93.94%
# Epoch 10: Loss = 0.1889
# Epoch 20: Loss = 0.1604
# Epoch 30: Loss = 0.1464
# Epoch 40: Loss = 0.1361
# Epoch 50: Loss = 0.1272
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 65354
# Percentage of ratings elicited: 94.85%
# Epoch 10: Loss = 0.1914
# Epoch 20: Loss = 0.1604
# Epoch 30: Loss = 0.1474
# Epoch 40: Loss = 0.1342
# Epoch 50: Loss = 0.1291
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 65997
# Percentage of ratings elicited: 95.79%
# Epoch 10: Loss = 0.1925
# Epoch 20: Loss = 0.1614
# Epoch 30: Loss = 0.1460
# Epoch 40: Loss = 0.1403
# Epoch 50: Loss = 0.1304
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 66932
# Percentage of ratings elicited: 97.14%
# Epoch 10: Loss = 0.1915
# Epoch 20: Loss = 0.1622
# Epoch 30: Loss = 0.1472
# Epoch 40: Loss = 0.1398
# Epoch 50: Loss = 0.1272
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67516
# Percentage of ratings elicited: 97.99%
# Epoch 10: Loss = 0.1967
# Epoch 20: Loss = 0.1635
# Epoch 30: Loss = 0.1481
# Epoch 40: Loss = 0.1398
# Epoch 50: Loss = 0.1327
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68054
# Percentage of ratings elicited: 98.77%
# Epoch 10: Loss = 0.1954
# Epoch 20: Loss = 0.1663
# Epoch 30: Loss = 0.1483
# Epoch 40: Loss = 0.1379
# Epoch 50: Loss = 0.1318
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68667
# Percentage of ratings elicited: 99.66%
# Epoch 10: Loss = 0.1998
# Epoch 20: Loss = 0.1675
# Epoch 30: Loss = 0.1535
# Epoch 40: Loss = 0.1431
# Epoch 50: Loss = 0.1337
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 5
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 10: Loss = 0.3555
# Epoch 20: Loss = 0.1423
# Epoch 30: Loss = 0.0536
# Epoch 40: Loss = 0.0225
# Epoch 50: Loss = 0.0143
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 10198
# Percentage of ratings elicited: 14.80%
# Epoch 10: Loss = 0.1902
# Epoch 20: Loss = 0.0708
# Epoch 30: Loss = 0.0425
# Epoch 40: Loss = 0.0368
# Epoch 50: Loss = 0.0250
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 18160
# Percentage of ratings elicited: 26.36%
# Epoch 10: Loss = 0.1228
# Epoch 20: Loss = 0.0662
# Epoch 30: Loss = 0.0538
# Epoch 40: Loss = 0.0426
# Epoch 50: Loss = 0.0385
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 25719
# Percentage of ratings elicited: 37.33%
# Epoch 10: Loss = 0.1257
# Epoch 20: Loss = 0.0796
# Epoch 30: Loss = 0.0655
# Epoch 40: Loss = 0.0561
# Epoch 50: Loss = 0.0522
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 33310
# Percentage of ratings elicited: 48.34%
# Epoch 10: Loss = 0.1266
# Epoch 20: Loss = 0.0895
# Epoch 30: Loss = 0.0779
# Epoch 40: Loss = 0.0662
# Epoch 50: Loss = 0.0650
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 39689
# Percentage of ratings elicited: 57.60%
# Epoch 10: Loss = 0.1325
# Epoch 20: Loss = 0.0976
# Epoch 30: Loss = 0.0868
# Epoch 40: Loss = 0.0788
# Epoch 50: Loss = 0.0733
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 44936
# Percentage of ratings elicited: 65.22%
# Epoch 10: Loss = 0.1361
# Epoch 20: Loss = 0.1064
# Epoch 30: Loss = 0.0943
# Epoch 40: Loss = 0.0849
# Epoch 50: Loss = 0.0811
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 49055
# Percentage of ratings elicited: 71.20%
# Epoch 10: Loss = 0.1446
# Epoch 20: Loss = 0.1177
# Epoch 30: Loss = 0.1044
# Epoch 40: Loss = 0.0956
# Epoch 50: Loss = 0.0870
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52243
# Percentage of ratings elicited: 75.82%
# Epoch 10: Loss = 0.1497
# Epoch 20: Loss = 0.1210
# Epoch 30: Loss = 0.1115
# Epoch 40: Loss = 0.0998
# Epoch 50: Loss = 0.0938
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54732
# Percentage of ratings elicited: 79.44%
# Epoch 10: Loss = 0.1520
# Epoch 20: Loss = 0.1272
# Epoch 30: Loss = 0.1154
# Epoch 40: Loss = 0.1048
# Epoch 50: Loss = 0.0997
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56823
# Percentage of ratings elicited: 82.47%
# Epoch 10: Loss = 0.1628
# Epoch 20: Loss = 0.1351
# Epoch 30: Loss = 0.1204
# Epoch 40: Loss = 0.1127
# Epoch 50: Loss = 0.1060
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58555
# Percentage of ratings elicited: 84.98%
# Epoch 10: Loss = 0.1655
# Epoch 20: Loss = 0.1365
# Epoch 30: Loss = 0.1233
# Epoch 40: Loss = 0.1182
# Epoch 50: Loss = 0.1066
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59998
# Percentage of ratings elicited: 87.08%
# Epoch 10: Loss = 0.1697
# Epoch 20: Loss = 0.1411
# Epoch 30: Loss = 0.1307
# Epoch 40: Loss = 0.1223
# Epoch 50: Loss = 0.1150
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61178
# Percentage of ratings elicited: 88.79%
# Epoch 10: Loss = 0.1750
# Epoch 20: Loss = 0.1484
# Epoch 30: Loss = 0.1348
# Epoch 40: Loss = 0.1240
# Epoch 50: Loss = 0.1167
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62146
# Percentage of ratings elicited: 90.20%
# Epoch 10: Loss = 0.1763
# Epoch 20: Loss = 0.1492
# Epoch 30: Loss = 0.1332
# Epoch 40: Loss = 0.1291
# Epoch 50: Loss = 0.1180
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 62796
# Percentage of ratings elicited: 91.14%
# Epoch 10: Loss = 0.1795
# Epoch 20: Loss = 0.1503
# Epoch 30: Loss = 0.1359
# Epoch 40: Loss = 0.1320
# Epoch 50: Loss = 0.1211
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63332
# Percentage of ratings elicited: 91.92%
# Epoch 10: Loss = 0.1817
# Epoch 20: Loss = 0.1535
# Epoch 30: Loss = 0.1389
# Epoch 40: Loss = 0.1301
# Epoch 50: Loss = 0.1206
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 63804
# Percentage of ratings elicited: 92.60%
# Epoch 10: Loss = 0.1853
# Epoch 20: Loss = 0.1546
# Epoch 30: Loss = 0.1415
# Epoch 40: Loss = 0.1324
# Epoch 50: Loss = 0.1278
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 64306
# Percentage of ratings elicited: 93.33%
# Epoch 10: Loss = 0.1876
# Epoch 20: Loss = 0.1581
# Epoch 30: Loss = 0.1437
# Epoch 40: Loss = 0.1331
# Epoch 50: Loss = 0.1287
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 64838
# Percentage of ratings elicited: 94.10%
# Epoch 10: Loss = 0.1890
# Epoch 20: Loss = 0.1593
# Epoch 30: Loss = 0.1467
# Epoch 40: Loss = 0.1344
# Epoch 50: Loss = 0.1297
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 65420
# Percentage of ratings elicited: 94.95%
# Epoch 10: Loss = 0.1917
# Epoch 20: Loss = 0.1596
# Epoch 30: Loss = 0.1473
# Epoch 40: Loss = 0.1361
# Epoch 50: Loss = 0.1292
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 66066
# Percentage of ratings elicited: 95.89%
# Epoch 10: Loss = 0.1915
# Epoch 20: Loss = 0.1611
# Epoch 30: Loss = 0.1482
# Epoch 40: Loss = 0.1366
# Epoch 50: Loss = 0.1276
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 66806
# Percentage of ratings elicited: 96.96%
# Epoch 10: Loss = 0.1897
# Epoch 20: Loss = 0.1637
# Epoch 30: Loss = 0.1462
# Epoch 40: Loss = 0.1376
# Epoch 50: Loss = 0.1293
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67550
# Percentage of ratings elicited: 98.04%
# Epoch 10: Loss = 0.1967
# Epoch 20: Loss = 0.1657
# Epoch 30: Loss = 0.1518
# Epoch 40: Loss = 0.1418
# Epoch 50: Loss = 0.1324
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68211
# Percentage of ratings elicited: 99.00%
# Epoch 10: Loss = 0.1991
# Epoch 20: Loss = 0.1671
# Epoch 30: Loss = 0.1526
# Epoch 40: Loss = 0.1412
# Epoch 50: Loss = 0.1333
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68671
# Percentage of ratings elicited: 99.67%
# Epoch 10: Loss = 0.1991
# Epoch 20: Loss = 0.1681
# Epoch 30: Loss = 0.1518
# Epoch 40: Loss = 0.1388
# Epoch 50: Loss = 0.1349

# %%
df_lst = []
for iter in range(n_iters):
    results = MaxRating_results_lst[iter]
    d = {}
    d['epoch'] = list(range(n_epochs))
    d['percentage'] = [r['percentage'] for r in results]
    d['map_pro'] = [r['map_pro'] for r in results]
    d['map_unpro'] = [r['map_unpro'] for r in results]
    d['ndcg_pro'] = [r['ndcg_pro'] for r in results]
    d['ndcg_unpro'] = [r['ndcg_unpro'] for r in results]
    d['precision_pro'] = [r['precision_pro'] for r in results]
    d['precision_unpro'] = [r['precision_unpro'] for r in results]
    d['recall_pro'] = [r['recall_pro'] for r in results]
    d['recall_unpro'] = [r['recall_unpro'] for r in results]
    d['rmse_pro'] = [r['rmse_pro'] for r in results]
    d['rmse_unpro'] = [r['rmse_unpro'] for r in results]
    d['rocauc_pro'] = [r['rocauc_pro'] for r in results]
    d['rocauc_unpro'] = [r['rocauc_unpro'] for r in results]
    d['agg_item_coverage_pro'] = [r['agg_item_coverage_pro'] for r in results]
    d['agg_item_coverage_unpro'] = [r['agg_item_coverage_unpro'] for r in results]
    d['avg_item_coverage_pro'] = [r['avg_item_coverage_pro'] for r in results]
    d['avg_item_coverage_unpro'] = [r['avg_item_coverage_unpro'] for r in results]
    d['count_pro'] = [r['count_pro'] for r in results]
    d['count_unpro'] = [r['count_unpro'] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

MaxRating_results_df = pd.concat(df_lst, axis=0, ignore_index=True)

# %%
MaxRating_results_df.to_csv('./outputs_pers_100k/MLP_MaxRating_exp1.csv')

# %% [markdown]
# ### Plots

# %%
MaxRating_results_df = pd.read_csv('./outputs_pers_100k/MLP_MaxRating_exp1.csv')

# %%
percentages = MaxRating_results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# precision
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# recall
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# RMSE
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('RMSE')

plt.legend()
plt.title("RMSE For Female and Male Users (MaxRating)")
plt.show()

# %%
# rocauc
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('AUCROC')

plt.legend()
plt.title("AUCROC For Female and Male Users (MaxRating)")
plt.show()

# %%
# aggregate item coverage
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['agg_item_coverage_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['agg_item_coverage_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Item Coverage')

plt.legend()
plt.title("Aggregate Item Coverage For Female and Male Users (MaxRating)")
plt.show()

# %%
# average individual item coverage
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['avg_item_coverage_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['avg_item_coverage_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Item Coverage')

plt.legend()
plt.title("Average Individual Item Coverage For Female and Male Users (MaxRating)")
plt.show()

# %%
# count
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(np.arange(pro_df_grouped.shape[0]), pro_df_grouped['mean'], color='tab:red', label="Female")

plt.plot(np.arange(unpro_df_grouped.shape[0]), unpro_df_grouped['mean'], color='tab:blue', label="Male")

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Rating count')

plt.legend()
plt.title("Rating Count For Female and Male Users (MaxRating)")
plt.show()

# %%
# response rate
count_df = MaxRating_results_df[['epoch', 'count_pro', 'count_unpro']]
mean_count_df = count_df.groupby('epoch').agg('mean')
collected_count_df = mean_count_df.diff()
collected_count_df = collected_count_df.iloc[1:]

collected_count_df['rate_pro'] = collected_count_df['count_pro'] / (q * n_female)
collected_count_df['rate_unpro'] = collected_count_df['count_unpro'] / (q * n_male)

x = np.arange(1, collected_count_df.shape[0]+1)
width = 0.3
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for col, label, c in zip(['rate_pro', 'rate_unpro'], ['Female', 'Male'], ['tab:red', 'tab:blue']):
    offset = width * multiplier
    rects = ax.bar(x + offset, collected_count_df[col], width, label=label, color=c)
    multiplier += 1

ax.set_ylabel('Response Rate')
ax.set_xlabel('# Epoch')
ax.set_xticks(x + width, x)
ax.legend()

plt.title("Response Rate For Female and Male Users (MaxRating)")
plt.show()

# %% [markdown]
# ## Nonpersonalized Active Learning

# %%
importlib.reload(ActiveLearner)
importlib.reload(LightGCN)
# Out:
# <module 'LightGCN' from '/Users/sipei/Tufts/Research/DeepALDataMinimization/LightGCN.py'>

# %%
# hyper-parameters

# hyper-parameter for rec sys
hparams = {
    'model_type': "neumf",
    'epochs': 600,
    'learning_rate': 0.005,
    'batch_size': 1024,
    'n_factors': 32,
    'layer_sizes': [32, 16, 8],
    'top_k': 10,
    'verbose': 100,
}


n_iters = 1   # number of repeated experiments
n_epochs = 26 # epoch of active learning process
q = 50        # active learning query list size

# %%
pop_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.NonpersonalizedActiveLearner(
        strategy = 'pop', 
        model = MLP.NCF,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=q,
        seed=iter,
        ratio=None,
    )
    pop_results_lst.append([])
    while al.i_indx < al.n_items:
        print('------------------------------------')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        pop_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# Epoch 100: Loss = 0.0130
# Epoch 200: Loss = 0.0042
# Epoch 300: Loss = 0.0013
# Epoch 400: Loss = 0.0021
# Epoch 500: Loss = 0.0008
# Epoch 600: Loss = 0.0004
# ------------------------------------
# # of ratings elicited: 15881
# Percentage of ratings elicited: 23.05%
# Epoch 100: Loss = 0.0167
# Epoch 200: Loss = 0.0091
# Epoch 300: Loss = 0.0076
# Epoch 400: Loss = 0.0034
# Epoch 500: Loss = 0.0020
# Epoch 600: Loss = 0.0021
# ------------------------------------
# # of ratings elicited: 23701
# Percentage of ratings elicited: 34.40%
# Epoch 100: Loss = 0.0300
# Epoch 200: Loss = 0.0186
# Epoch 300: Loss = 0.0172
# Epoch 400: Loss = 0.0119
# Epoch 500: Loss = 0.0130
# Epoch 600: Loss = 0.0095
# ------------------------------------
# # of ratings elicited: 30075
# Percentage of ratings elicited: 43.65%
# Epoch 100: Loss = 0.0405
# Epoch 200: Loss = 0.0281
# Epoch 300: Loss = 0.0254
# Epoch 400: Loss = 0.0214
# Epoch 500: Loss = 0.0182
# Epoch 600: Loss = 0.0138
# ------------------------------------
# # of ratings elicited: 35408
# Percentage of ratings elicited: 51.39%
# Epoch 100: Loss = 0.0479
# Epoch 200: Loss = 0.0384
# Epoch 300: Loss = 0.0315
# Epoch 400: Loss = 0.0290
# Epoch 500: Loss = 0.0251
# Epoch 600: Loss = 0.0209
# ------------------------------------
# # of ratings elicited: 39937
# Percentage of ratings elicited: 57.96%
# Epoch 100: Loss = 0.0597
# Epoch 200: Loss = 0.0479
# Epoch 300: Loss = 0.0410
# Epoch 400: Loss = 0.0344
# Epoch 500: Loss = 0.0332
# Epoch 600: Loss = 0.0312
# ------------------------------------
# # of ratings elicited: 43943
# Percentage of ratings elicited: 63.78%
# Epoch 100: Loss = 0.0695
# Epoch 200: Loss = 0.0536
# Epoch 300: Loss = 0.0485
# Epoch 400: Loss = 0.0444
# Epoch 500: Loss = 0.0383
# Epoch 600: Loss = 0.0370
# ------------------------------------
# # of ratings elicited: 47340
# Percentage of ratings elicited: 68.71%
# Epoch 100: Loss = 0.0748
# Epoch 200: Loss = 0.0640
# Epoch 300: Loss = 0.0555
# Epoch 400: Loss = 0.0506
# Epoch 500: Loss = 0.0469
# Epoch 600: Loss = 0.0428
# ------------------------------------
# # of ratings elicited: 50268
# Percentage of ratings elicited: 72.96%
# Epoch 100: Loss = 0.0786
# Epoch 200: Loss = 0.0634
# Epoch 300: Loss = 0.0579
# Epoch 400: Loss = 0.0522
# Epoch 500: Loss = 0.0476
# Epoch 600: Loss = 0.0431
# ------------------------------------
# # of ratings elicited: 52801
# Percentage of ratings elicited: 76.63%
# Epoch 100: Loss = 0.0861
# Epoch 200: Loss = 0.0661
# Epoch 300: Loss = 0.0606
# Epoch 400: Loss = 0.0564
# Epoch 500: Loss = 0.0530
# Epoch 600: Loss = 0.0481
# ------------------------------------
# # of ratings elicited: 55071
# Percentage of ratings elicited: 79.93%
# Epoch 100: Loss = 0.0913
# Epoch 200: Loss = 0.0715
# Epoch 300: Loss = 0.0664
# Epoch 400: Loss = 0.0598
# Epoch 500: Loss = 0.0553
# Epoch 600: Loss = 0.0540
# ------------------------------------
# # of ratings elicited: 57083
# Percentage of ratings elicited: 82.85%
# Epoch 100: Loss = 0.0915
# Epoch 200: Loss = 0.0742
# Epoch 300: Loss = 0.0687
# Epoch 400: Loss = 0.0610
# Epoch 500: Loss = 0.0566
# Epoch 600: Loss = 0.0567
# ------------------------------------
# # of ratings elicited: 58869
# Percentage of ratings elicited: 85.44%
# Epoch 100: Loss = 0.0978
# Epoch 200: Loss = 0.0786
# Epoch 300: Loss = 0.0715
# Epoch 400: Loss = 0.0647
# Epoch 500: Loss = 0.0588
# Epoch 600: Loss = 0.0584
# ------------------------------------
# # of ratings elicited: 60405
# Percentage of ratings elicited: 87.67%
# Epoch 100: Loss = 0.0988
# Epoch 200: Loss = 0.0795
# Epoch 300: Loss = 0.0703
# Epoch 400: Loss = 0.0653
# Epoch 500: Loss = 0.0599
# Epoch 600: Loss = 0.0587
# ------------------------------------
# # of ratings elicited: 61776
# Percentage of ratings elicited: 89.66%
# Epoch 100: Loss = 0.1008
# Epoch 200: Loss = 0.0828
# Epoch 300: Loss = 0.0744
# Epoch 400: Loss = 0.0685
# Epoch 500: Loss = 0.0656
# Epoch 600: Loss = 0.0636
# ------------------------------------
# # of ratings elicited: 62996
# Percentage of ratings elicited: 91.43%
# Epoch 100: Loss = 0.1039
# Epoch 200: Loss = 0.0833
# Epoch 300: Loss = 0.0731
# Epoch 400: Loss = 0.0677
# Epoch 500: Loss = 0.0648
# Epoch 600: Loss = 0.0617
# ------------------------------------
# # of ratings elicited: 64037
# Percentage of ratings elicited: 92.94%
# Epoch 100: Loss = 0.1067
# Epoch 200: Loss = 0.0832
# Epoch 300: Loss = 0.0761
# Epoch 400: Loss = 0.0705
# Epoch 500: Loss = 0.0672
# Epoch 600: Loss = 0.0629
# ------------------------------------
# # of ratings elicited: 64952
# Percentage of ratings elicited: 94.27%
# Epoch 100: Loss = 0.1044
# Epoch 200: Loss = 0.0859
# Epoch 300: Loss = 0.0789
# Epoch 400: Loss = 0.0725
# Epoch 500: Loss = 0.0662
# Epoch 600: Loss = 0.0628
# ------------------------------------
# # of ratings elicited: 65745
# Percentage of ratings elicited: 95.42%
# Epoch 100: Loss = 0.1069
# Epoch 200: Loss = 0.0885
# Epoch 300: Loss = 0.0759
# Epoch 400: Loss = 0.0700
# Epoch 500: Loss = 0.0675
# Epoch 600: Loss = 0.0652
# ------------------------------------
# # of ratings elicited: 66402
# Percentage of ratings elicited: 96.37%
# Epoch 100: Loss = 0.1092
# Epoch 200: Loss = 0.0889
# Epoch 300: Loss = 0.0789
# Epoch 400: Loss = 0.0728
# Epoch 500: Loss = 0.0663
# Epoch 600: Loss = 0.0625
# ------------------------------------
# # of ratings elicited: 66969
# Percentage of ratings elicited: 97.20%
# Epoch 100: Loss = 0.1070
# Epoch 200: Loss = 0.0891
# Epoch 300: Loss = 0.0786
# Epoch 400: Loss = 0.0695
# Epoch 500: Loss = 0.0667
# Epoch 600: Loss = 0.0641
# ------------------------------------
# # of ratings elicited: 67458
# Percentage of ratings elicited: 97.91%
# Epoch 100: Loss = 0.1082
# Epoch 200: Loss = 0.0866
# Epoch 300: Loss = 0.0767
# Epoch 400: Loss = 0.0722
# Epoch 500: Loss = 0.0675
# Epoch 600: Loss = 0.0641
# ------------------------------------
# # of ratings elicited: 67858
# Percentage of ratings elicited: 98.49%
# Epoch 100: Loss = 0.1096
# Epoch 200: Loss = 0.0899
# Epoch 300: Loss = 0.0794
# Epoch 400: Loss = 0.0729
# Epoch 500: Loss = 0.0673
# Epoch 600: Loss = 0.0638
# ------------------------------------
# # of ratings elicited: 68204
# Percentage of ratings elicited: 98.99%
# Epoch 100: Loss = 0.1083
# Epoch 200: Loss = 0.0892
# Epoch 300: Loss = 0.0771
# Epoch 400: Loss = 0.0732
# Epoch 500: Loss = 0.0682
# Epoch 600: Loss = 0.0661
# ------------------------------------
# # of ratings elicited: 68510
# Percentage of ratings elicited: 99.43%
# Epoch 100: Loss = 0.1073
# Epoch 200: Loss = 0.0862
# Epoch 300: Loss = 0.0777
# Epoch 400: Loss = 0.0708
# Epoch 500: Loss = 0.0673
# Epoch 600: Loss = 0.0627
# ------------------------------------
# # of ratings elicited: 68754
# Percentage of ratings elicited: 99.79%
# Epoch 100: Loss = 0.1060
# Epoch 200: Loss = 0.0884
# Epoch 300: Loss = 0.0798
# Epoch 400: Loss = 0.0739
# Epoch 500: Loss = 0.0674
# Epoch 600: Loss = 0.0658

# %%
df_lst = []
for iter in range(n_iters):
    results = pop_results_lst[iter]
    d = {}
    d['epoch'] = list(range(len(pop_results_lst[0])))
    d['percentage'] = [r['percentage'] for r in results]
    d['map_pro'] = [r['map_pro'] for r in results]
    d['map_unpro'] = [r['map_unpro'] for r in results]
    d['ndcg_pro'] = [r['ndcg_pro'] for r in results]
    d['ndcg_unpro'] = [r['ndcg_unpro'] for r in results]
    d['precision_pro'] = [r['precision_pro'] for r in results]
    d['precision_unpro'] = [r['precision_unpro'] for r in results]
    d['recall_pro'] = [r['recall_pro'] for r in results]
    d['recall_unpro'] = [r['recall_unpro'] for r in results]
    d['rmse_pro'] = [r['rmse_pro'] for r in results]
    d['rmse_unpro'] = [r['rmse_unpro'] for r in results]
    d['rocauc_pro'] = [r['rocauc_pro'] for r in results]
    d['rocauc_unpro'] = [r['rocauc_unpro'] for r in results]
    d['count_pro'] = [r['count_pro'] for r in results]
    d['count_unpro'] = [r['count_unpro'] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

results_df = pd.concat(df_lst, axis=0)

# %%
results_df.to_csv('./outputs_nonpers_100k/pop_exp1.csv')

# %%
percentages = results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# precision
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# recall
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# rmse
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('RMSE')

plt.legend()
plt.title("RMSE For Female and Male Users (Popularity)")
plt.show()

# %%
# rocauc
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('AUCROC')

plt.legend()
plt.title("AUCROC For Female and Male Users (Popularity)")
plt.show()

# %%
# count
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(np.arange(pro_df_grouped.shape[0]), pro_df_grouped['mean'], color='tab:red', label="Female")

plt.plot(np.arange(unpro_df_grouped.shape[0]), unpro_df_grouped['mean'], color='tab:blue', label="Male")

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Rating count')

plt.legend()
plt.title("Rating count For Female and Male Users (Popularity)")
plt.show()

# %%
# response rate
count_df = results_df[['epoch', 'count_pro', 'count_unpro']]
mean_count_df = count_df.groupby('epoch').agg('mean')
collected_count_df = mean_count_df.diff()
collected_count_df = collected_count_df.iloc[1:]

collected_count_df['rate_pro'] = collected_count_df['count_pro'] / (q * n_female)
collected_count_df['rate_unpro'] = collected_count_df['count_unpro'] / (q * n_male)

x = np.arange(1, collected_count_df.shape[0]+1)
width = 0.3
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for col, label, c in zip(['rate_pro', 'rate_unpro'], ['Female', 'Male'], ['tab:red', 'tab:blue']):
    offset = width * multiplier
    rects = ax.bar(x + offset, collected_count_df[col], width, label=label, color=c)
    multiplier += 1

ax.set_ylabel('Response Rate')
ax.set_xlabel('# Epoch')
ax.set_xticks(x + width, x)
ax.legend()

plt.title("Response Rate For Female and Male Users (Popularity)")
plt.show()
