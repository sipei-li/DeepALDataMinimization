# %%
import numpy as np
import pandas as pd
import tensorflow as tf 
import scipy.sparse as sp
from recommenders.evaluation.python_evaluation import (
    map_at_k,
    ndcg_at_k,
    precision_at_k,
    recall_at_k,
)

import LightGCN
from utils import get_top_k_scored_items, nCoreReduction, user_fixed_train_test_split

import matplotlib.pyplot as plt 

import importlib 

import ActiveLearner

# disable the SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Load data

# %%
data_url = "https://files.grouplens.org/datasets/movielens/ml-100k/u.data"
data_columns = ['user_id', 'item_id', 'rating', 'timestamp']

user_url = "https://files.grouplens.org/datasets/movielens/ml-100k/u.user"
user_columns = ['user_id', 'age', 'gender', 'occupation', 'zip_code']

# %%
data_df = pd.read_csv(data_url, sep='\t', names=data_columns, header=None)
user_df = pd.read_csv(user_url, sep='|', names=user_columns, header=None)

# %%
# shuffle data_df
data_df = data_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Convert to implicit feedback
#
# **Note**: For MovieLens 100k dataset, we are converting a rating in the range [1, 5] to an implicit feedback of 1 so that we still have a significant number of positive samples in the dataset. For MovieLens 1M, we could do [3, 5] instead.
#
# We might not need this.

# %%
# data_df['rating'] = (data_df['rating'] >= 1).astype(int)

# %% [markdown]
# ## Dimensionality reduction
#
# Only keep:
# - users that provided at least 5 ratings
# - items that received at least 5 ratings

# %%
ncore_data_df = nCoreReduction(data_df)

# %%
print(f"The original data frame shape: {data_df.shape}")
print(f"  - # users: {data_df['user_id'].nunique()}")
print(f"  - # items: {data_df['item_id'].nunique()}")
print('\n')

print(f"The filtered data frame shape: {ncore_data_df.shape}")
print(f"  - # users: {ncore_data_df['user_id'].nunique()}")
print(f"  - # items: {ncore_data_df['item_id'].nunique()}")
# Out:
# The original data frame shape: (100000, 4)
#   - # users: 943
#   - # items: 1682
#
#
# The filtered data frame shape: (99032, 4)
#   - # users: 943
#   - # items: 1298

# %% [markdown]
# ## Convert id to inner id

# %%
unique_users = ncore_data_df['user_id'].unique()
user_id_to_iid = {id: iid for iid, id in enumerate(unique_users)}
user_iid_to_id = {iid: id for iid, id in enumerate(unique_users)}

unique_items = ncore_data_df['item_id'].unique()
item_id_to_iid = {id: iid for iid, id in enumerate(unique_items)}
item_iid_to_id = {iid: id for iid, id in enumerate(unique_items)}

# %%
n_users = unique_users.shape[0]
n_items = unique_items.shape[0]

# %%
ncore_data_df['user_iid'] = ncore_data_df['user_id'].map(user_id_to_iid)
ncore_data_df['item_iid'] = ncore_data_df['item_id'].map(item_id_to_iid)

# apply to `user_df`` as well
user_df['user_iid'] = user_df['user_id'].map(user_id_to_iid)

# %%
iid_to_gender = dict(zip(user_df['user_iid'], user_df['gender']))

# %%
n_female, n_male = user_df['gender'].value_counts()[['F', 'M']]
print(f"Number of female users: {n_female}")
print(f"Number of male users: {n_male}")
# Out:
# Number of female users: 273
# Number of male users: 670

# %% [markdown]
# ## Train test split (user-fixed)

# %%
train_df, test_df = user_fixed_train_test_split(ncore_data_df, test_size=0.2, random_state=42)

# %% [markdown]
# ## Personalized Active Learning

# %%
importlib.reload(ActiveLearner)
importlib.reload(LightGCN)
# Out:
# <module 'LightGCN' from '/Users/sipei/Tufts/Research/DeepALDataMinimization/LightGCN.py'>

# %%
# hyper-parameters

# hyper-parameter for rec sys
hparams = {
    'epochs': 50,
    'learning_rate': 0.005,
    'embed_size': 64,
    'batch_size': 1024,
    'n_layers': 3,
    'decay': 0.0001,
    'eval_epoch': -1,
    'top_k': 10,
}


n_iters = 5   # number of repeated experiments
n_epochs = 26 # epoch of active learning process
q = 50        # active learning query list size

# %%
MaxRating_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.RatingBasedActiveLearner(
        strategy = 'MaxRating', 
        model = LightGCN.LightGCNRecommender,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=q,
        seed=iter,
        ratio=None,
    )
    MaxRating_results_lst.append([])
    for epoch in range(n_epochs):
        print('------------------------------------')
        print(f'Epoch: {epoch+1}')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        MaxRating_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 12942
# Percentage of ratings elicited: 16.41%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 25470
# Percentage of ratings elicited: 32.30%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 35946
# Percentage of ratings elicited: 45.59%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 43429
# Percentage of ratings elicited: 55.08%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 49142
# Percentage of ratings elicited: 62.33%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 53780
# Percentage of ratings elicited: 68.21%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 57420
# Percentage of ratings elicited: 72.83%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 60609
# Percentage of ratings elicited: 76.87%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 63445
# Percentage of ratings elicited: 80.47%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 65677
# Percentage of ratings elicited: 83.30%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 67421
# Percentage of ratings elicited: 85.51%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 68943
# Percentage of ratings elicited: 87.44%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 70309
# Percentage of ratings elicited: 89.17%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 71493
# Percentage of ratings elicited: 90.67%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 72673
# Percentage of ratings elicited: 92.17%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 73668
# Percentage of ratings elicited: 93.43%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 74427
# Percentage of ratings elicited: 94.40%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 74969
# Percentage of ratings elicited: 95.08%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 75495
# Percentage of ratings elicited: 95.75%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 76088
# Percentage of ratings elicited: 96.50%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 76904
# Percentage of ratings elicited: 97.54%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 77609
# Percentage of ratings elicited: 98.43%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 78130
# Percentage of ratings elicited: 99.09%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 78491
# Percentage of ratings elicited: 99.55%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 78771
# Percentage of ratings elicited: 99.90%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 2
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 13136
# Percentage of ratings elicited: 16.66%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 25655
# Percentage of ratings elicited: 32.54%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 36149
# Percentage of ratings elicited: 45.85%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 43796
# Percentage of ratings elicited: 55.55%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 49595
# Percentage of ratings elicited: 62.90%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 54226
# Percentage of ratings elicited: 68.77%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 58082
# Percentage of ratings elicited: 73.67%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 61089
# Percentage of ratings elicited: 77.48%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 63637
# Percentage of ratings elicited: 80.71%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 65777
# Percentage of ratings elicited: 83.42%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 67545
# Percentage of ratings elicited: 85.67%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 69276
# Percentage of ratings elicited: 87.86%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 70719
# Percentage of ratings elicited: 89.69%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 72044
# Percentage of ratings elicited: 91.37%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 73102
# Percentage of ratings elicited: 92.71%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 73931
# Percentage of ratings elicited: 93.77%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 74547
# Percentage of ratings elicited: 94.55%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 75193
# Percentage of ratings elicited: 95.37%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 75867
# Percentage of ratings elicited: 96.22%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 76366
# Percentage of ratings elicited: 96.85%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 76950
# Percentage of ratings elicited: 97.60%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 77541
# Percentage of ratings elicited: 98.34%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 77986
# Percentage of ratings elicited: 98.91%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 78468
# Percentage of ratings elicited: 99.52%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 78785
# Percentage of ratings elicited: 99.92%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 3
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 13130
# Percentage of ratings elicited: 16.65%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 25827
# Percentage of ratings elicited: 32.76%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 36096
# Percentage of ratings elicited: 45.78%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 43378
# Percentage of ratings elicited: 55.02%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 49146
# Percentage of ratings elicited: 62.33%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 53556
# Percentage of ratings elicited: 67.92%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 57264
# Percentage of ratings elicited: 72.63%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 60547
# Percentage of ratings elicited: 76.79%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 63447
# Percentage of ratings elicited: 80.47%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 65849
# Percentage of ratings elicited: 83.52%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 67930
# Percentage of ratings elicited: 86.16%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 69682
# Percentage of ratings elicited: 88.38%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 70994
# Percentage of ratings elicited: 90.04%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 72157
# Percentage of ratings elicited: 91.52%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 73153
# Percentage of ratings elicited: 92.78%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 73947
# Percentage of ratings elicited: 93.79%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 74587
# Percentage of ratings elicited: 94.60%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 75328
# Percentage of ratings elicited: 95.54%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 75934
# Percentage of ratings elicited: 96.31%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 76425
# Percentage of ratings elicited: 96.93%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 77075
# Percentage of ratings elicited: 97.75%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 77622
# Percentage of ratings elicited: 98.45%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 78065
# Percentage of ratings elicited: 99.01%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 78472
# Percentage of ratings elicited: 99.53%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 78764
# Percentage of ratings elicited: 99.90%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 4
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 12804
# Percentage of ratings elicited: 16.24%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 25250
# Percentage of ratings elicited: 32.02%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 36036
# Percentage of ratings elicited: 45.70%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 43624
# Percentage of ratings elicited: 55.33%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 49276
# Percentage of ratings elicited: 62.50%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 53756
# Percentage of ratings elicited: 68.18%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 57578
# Percentage of ratings elicited: 73.03%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 60866
# Percentage of ratings elicited: 77.20%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 63495
# Percentage of ratings elicited: 80.53%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 65852
# Percentage of ratings elicited: 83.52%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 67841
# Percentage of ratings elicited: 86.04%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 69563
# Percentage of ratings elicited: 88.23%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 70932
# Percentage of ratings elicited: 89.96%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 72101
# Percentage of ratings elicited: 91.45%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 73131
# Percentage of ratings elicited: 92.75%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 73963
# Percentage of ratings elicited: 93.81%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 74580
# Percentage of ratings elicited: 94.59%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 75162
# Percentage of ratings elicited: 95.33%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 75791
# Percentage of ratings elicited: 96.13%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 76354
# Percentage of ratings elicited: 96.84%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 76940
# Percentage of ratings elicited: 97.58%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 77474
# Percentage of ratings elicited: 98.26%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 77994
# Percentage of ratings elicited: 98.92%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 78487
# Percentage of ratings elicited: 99.54%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 78778
# Percentage of ratings elicited: 99.91%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 5
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 13002
# Percentage of ratings elicited: 16.49%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 25773
# Percentage of ratings elicited: 32.69%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 36049
# Percentage of ratings elicited: 45.72%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 43548
# Percentage of ratings elicited: 55.23%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 49310
# Percentage of ratings elicited: 62.54%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 53840
# Percentage of ratings elicited: 68.29%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 57578
# Percentage of ratings elicited: 73.03%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 60678
# Percentage of ratings elicited: 76.96%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 63244
# Percentage of ratings elicited: 80.21%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 65550
# Percentage of ratings elicited: 83.14%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 67522
# Percentage of ratings elicited: 85.64%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 69188
# Percentage of ratings elicited: 87.75%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 70574
# Percentage of ratings elicited: 89.51%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 71707
# Percentage of ratings elicited: 90.95%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 72815
# Percentage of ratings elicited: 92.35%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 73709
# Percentage of ratings elicited: 93.48%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 74421
# Percentage of ratings elicited: 94.39%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 75037
# Percentage of ratings elicited: 95.17%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 75692
# Percentage of ratings elicited: 96.00%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 76307
# Percentage of ratings elicited: 96.78%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 76917
# Percentage of ratings elicited: 97.55%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 77452
# Percentage of ratings elicited: 98.23%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 78084
# Percentage of ratings elicited: 99.03%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 78510
# Percentage of ratings elicited: 99.57%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 78768
# Percentage of ratings elicited: 99.90%

# %%
df_lst = []
for iter in range(n_iters):
    results = MaxRating_results_lst[iter]
    d = {}
    d['epoch'] = list(range(n_epochs))
    d['percentage'] = [r['percentage'] for r in results]
    d['map_pro'] = [r['map_pro'] for r in results]
    d['map_unpro'] = [r['map_unpro'] for r in results]
    d['ndcg_pro'] = [r['ndcg_pro'] for r in results]
    d['ndcg_unpro'] = [r['ndcg_unpro'] for r in results]
    d['precision_pro'] = [r['precision_pro'] for r in results]
    d['precision_unpro'] = [r['precision_unpro'] for r in results]
    d['recall_pro'] = [r['recall_pro'] for r in results]
    d['recall_unpro'] = [r['recall_unpro'] for r in results]
    d['count_pro'] = [r['count_pro'] for r in results]
    d['count_unpro'] = [r['count_unpro'] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

MaxRating_results_df = pd.concat(df_lst, axis=0, ignore_index=True)

# %%
MaxRating_results_df.to_csv('./outputs_pers_100k/MaxRating_exp1.csv')

# %% [markdown]
# ### Plots

# %%
percentages = MaxRating_results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# precision
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# recall
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# count
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(np.arange(n_epochs), pro_df_grouped['mean'], color='tab:red', label="Female")

plt.plot(np.arange(n_epochs), unpro_df_grouped['mean'], color='tab:blue', label="Male")

plt.xlabel('Number of epoch')
plt.ylabel('Rating count')

plt.legend()
plt.title("Rating count For Female and Male Users (MaxRating)")
plt.show()

# %%
# response rate
count_df = MaxRating_results_df[['epoch', 'count_pro', 'count_unpro']]
mean_count_df = count_df.groupby('epoch').agg('mean')
collected_count_df = mean_count_df.diff()
collected_count_df = collected_count_df.iloc[1:]

collected_count_df['rate_pro'] = collected_count_df['count_pro'] / (q * n_female)
collected_count_df['rate_unpro'] = collected_count_df['count_unpro'] / (q * n_male)

x = np.arange(1, n_epochs)
width = 0.3
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for col, label, c in zip(['rate_pro', 'rate_unpro'], ['Female', 'Male'], ['tab:red', 'tab:blue']):
    offset = width * multiplier
    rects = ax.bar(x + offset, collected_count_df[col], width, label=label, color=c)
    multiplier += 1

ax.set_ylabel('Response Rate')
ax.set_xlabel('# Epoch')
ax.set_xticks(x + width, x)
ax.legend()

plt.show()

# %% [markdown]
# ## Nonpersonalized Active Learning

# %%
importlib.reload(ActiveLearner)
importlib.reload(LightGCN)
# Out:
# <module 'LightGCN' from '/Users/sipei/Tufts/Research/DeepALDataMinimization/LightGCN.py'>

# %%
hparams = {
    'epochs': 50,
    'learning_rate': 0.005,
    'embed_size': 64,
    'batch_size': 1024,
    'n_layers': 3,
    'decay': 0.0001,
    'eval_epoch': -1,
    'top_k': 10,
}

n_iters = 5
n_epochs = 30

# %%
pop_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.NonpersonalizedActiveLearner(
        strategy = 'pop', 
        model = LightGCN.LightGCNRecommender,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=50,
        seed=iter,
        ratio=None,
    )
    pop_results_lst.append([])
    while al.i_indx < al.n_items:
        print('------------------------------------')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        pop_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 17451
# Percentage of ratings elicited: 22.13%
# ------------------------------------
# # of ratings elicited: 26613
# Percentage of ratings elicited: 33.75%
# ------------------------------------
# # of ratings elicited: 33944
# Percentage of ratings elicited: 43.05%
# ------------------------------------
# # of ratings elicited: 40160
# Percentage of ratings elicited: 50.93%
# ------------------------------------
# # of ratings elicited: 45426
# Percentage of ratings elicited: 57.61%
# ------------------------------------
# # of ratings elicited: 50069
# Percentage of ratings elicited: 63.50%
# ------------------------------------
# # of ratings elicited: 53963
# Percentage of ratings elicited: 68.44%
# ------------------------------------
# # of ratings elicited: 57337
# Percentage of ratings elicited: 72.72%
# ------------------------------------
# # of ratings elicited: 60304
# Percentage of ratings elicited: 76.48%
# ------------------------------------
# # of ratings elicited: 62888
# Percentage of ratings elicited: 79.76%
# ------------------------------------
# # of ratings elicited: 65223
# Percentage of ratings elicited: 82.72%
# ------------------------------------
# # of ratings elicited: 67267
# Percentage of ratings elicited: 85.31%
# ------------------------------------
# # of ratings elicited: 69033
# Percentage of ratings elicited: 87.55%
# ------------------------------------
# # of ratings elicited: 70630
# Percentage of ratings elicited: 89.58%
# ------------------------------------
# # of ratings elicited: 72042
# Percentage of ratings elicited: 91.37%
# ------------------------------------
# # of ratings elicited: 73251
# Percentage of ratings elicited: 92.90%
# ------------------------------------
# # of ratings elicited: 74294
# Percentage of ratings elicited: 94.23%
# ------------------------------------
# # of ratings elicited: 75194
# Percentage of ratings elicited: 95.37%
# ------------------------------------
# # of ratings elicited: 75960
# Percentage of ratings elicited: 96.34%
# ------------------------------------
# # of ratings elicited: 76617
# Percentage of ratings elicited: 97.17%
# ------------------------------------
# # of ratings elicited: 77164
# Percentage of ratings elicited: 97.87%
# ------------------------------------
# # of ratings elicited: 77627
# Percentage of ratings elicited: 98.45%
# ------------------------------------
# # of ratings elicited: 78027
# Percentage of ratings elicited: 98.96%
# ------------------------------------
# # of ratings elicited: 78364
# Percentage of ratings elicited: 99.39%
# ------------------------------------
# # of ratings elicited: 78652
# Percentage of ratings elicited: 99.75%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 2
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 17429
# Percentage of ratings elicited: 22.11%
# ------------------------------------
# # of ratings elicited: 26624
# Percentage of ratings elicited: 33.77%
# ------------------------------------
# # of ratings elicited: 33986
# Percentage of ratings elicited: 43.10%
# ------------------------------------
# # of ratings elicited: 40186
# Percentage of ratings elicited: 50.97%
# ------------------------------------
# # of ratings elicited: 45460
# Percentage of ratings elicited: 57.66%
# ------------------------------------
# # of ratings elicited: 50064
# Percentage of ratings elicited: 63.50%
# ------------------------------------
# # of ratings elicited: 53974
# Percentage of ratings elicited: 68.45%
# ------------------------------------
# # of ratings elicited: 57325
# Percentage of ratings elicited: 72.71%
# ------------------------------------
# # of ratings elicited: 60289
# Percentage of ratings elicited: 76.46%
# ------------------------------------
# # of ratings elicited: 62881
# Percentage of ratings elicited: 79.75%
# ------------------------------------
# # of ratings elicited: 65215
# Percentage of ratings elicited: 82.71%
# ------------------------------------
# # of ratings elicited: 67260
# Percentage of ratings elicited: 85.31%
# ------------------------------------
# # of ratings elicited: 69031
# Percentage of ratings elicited: 87.55%
# ------------------------------------
# # of ratings elicited: 70615
# Percentage of ratings elicited: 89.56%
# ------------------------------------
# # of ratings elicited: 72018
# Percentage of ratings elicited: 91.34%
# ------------------------------------
# # of ratings elicited: 73220
# Percentage of ratings elicited: 92.86%
# ------------------------------------
# # of ratings elicited: 74286
# Percentage of ratings elicited: 94.22%
# ------------------------------------
# # of ratings elicited: 75187
# Percentage of ratings elicited: 95.36%
# ------------------------------------
# # of ratings elicited: 75972
# Percentage of ratings elicited: 96.35%
# ------------------------------------
# # of ratings elicited: 76613
# Percentage of ratings elicited: 97.17%
# ------------------------------------
# # of ratings elicited: 77157
# Percentage of ratings elicited: 97.86%
# ------------------------------------
# # of ratings elicited: 77620
# Percentage of ratings elicited: 98.45%
# ------------------------------------
# # of ratings elicited: 78023
# Percentage of ratings elicited: 98.96%
# ------------------------------------
# # of ratings elicited: 78359
# Percentage of ratings elicited: 99.38%
# ------------------------------------
# # of ratings elicited: 78647
# Percentage of ratings elicited: 99.75%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 3
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 17443
# Percentage of ratings elicited: 22.12%
# ------------------------------------
# # of ratings elicited: 26683
# Percentage of ratings elicited: 33.84%
# ------------------------------------
# # of ratings elicited: 34033
# Percentage of ratings elicited: 43.16%
# ------------------------------------
# # of ratings elicited: 40237
# Percentage of ratings elicited: 51.03%
# ------------------------------------
# # of ratings elicited: 45521
# Percentage of ratings elicited: 57.73%
# ------------------------------------
# # of ratings elicited: 50134
# Percentage of ratings elicited: 63.58%
# ------------------------------------
# # of ratings elicited: 54023
# Percentage of ratings elicited: 68.52%
# ------------------------------------
# # of ratings elicited: 57391
# Percentage of ratings elicited: 72.79%
# ------------------------------------
# # of ratings elicited: 60338
# Percentage of ratings elicited: 76.53%
# ------------------------------------
# # of ratings elicited: 62925
# Percentage of ratings elicited: 79.81%
# ------------------------------------
# # of ratings elicited: 65247
# Percentage of ratings elicited: 82.75%
# ------------------------------------
# # of ratings elicited: 67285
# Percentage of ratings elicited: 85.34%
# ------------------------------------
# # of ratings elicited: 69032
# Percentage of ratings elicited: 87.55%
# ------------------------------------
# # of ratings elicited: 70623
# Percentage of ratings elicited: 89.57%
# ------------------------------------
# # of ratings elicited: 72033
# Percentage of ratings elicited: 91.36%
# ------------------------------------
# # of ratings elicited: 73229
# Percentage of ratings elicited: 92.88%
# ------------------------------------
# # of ratings elicited: 74287
# Percentage of ratings elicited: 94.22%
# ------------------------------------
# # of ratings elicited: 75195
# Percentage of ratings elicited: 95.37%
# ------------------------------------
# # of ratings elicited: 75965
# Percentage of ratings elicited: 96.35%
# ------------------------------------
# # of ratings elicited: 76613
# Percentage of ratings elicited: 97.17%
# ------------------------------------
# # of ratings elicited: 77156
# Percentage of ratings elicited: 97.86%
# ------------------------------------
# # of ratings elicited: 77622
# Percentage of ratings elicited: 98.45%
# ------------------------------------
# # of ratings elicited: 78020
# Percentage of ratings elicited: 98.95%
# ------------------------------------
# # of ratings elicited: 78359
# Percentage of ratings elicited: 99.38%
# ------------------------------------
# # of ratings elicited: 78645
# Percentage of ratings elicited: 99.75%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 4
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 17419
# Percentage of ratings elicited: 22.09%
# ------------------------------------
# # of ratings elicited: 26634
# Percentage of ratings elicited: 33.78%
# ------------------------------------
# # of ratings elicited: 33964
# Percentage of ratings elicited: 43.08%
# ------------------------------------
# # of ratings elicited: 40209
# Percentage of ratings elicited: 51.00%
# ------------------------------------
# # of ratings elicited: 45468
# Percentage of ratings elicited: 57.67%
# ------------------------------------
# # of ratings elicited: 50087
# Percentage of ratings elicited: 63.53%
# ------------------------------------
# # of ratings elicited: 53990
# Percentage of ratings elicited: 68.48%
# ------------------------------------
# # of ratings elicited: 57376
# Percentage of ratings elicited: 72.77%
# ------------------------------------
# # of ratings elicited: 60321
# Percentage of ratings elicited: 76.50%
# ------------------------------------
# # of ratings elicited: 62926
# Percentage of ratings elicited: 79.81%
# ------------------------------------
# # of ratings elicited: 65247
# Percentage of ratings elicited: 82.75%
# ------------------------------------
# # of ratings elicited: 67296
# Percentage of ratings elicited: 85.35%
# ------------------------------------
# # of ratings elicited: 69039
# Percentage of ratings elicited: 87.56%
# ------------------------------------
# # of ratings elicited: 70627
# Percentage of ratings elicited: 89.58%
# ------------------------------------
# # of ratings elicited: 72033
# Percentage of ratings elicited: 91.36%
# ------------------------------------
# # of ratings elicited: 73238
# Percentage of ratings elicited: 92.89%
# ------------------------------------
# # of ratings elicited: 74288
# Percentage of ratings elicited: 94.22%
# ------------------------------------
# # of ratings elicited: 75190
# Percentage of ratings elicited: 95.36%
# ------------------------------------
# # of ratings elicited: 75961
# Percentage of ratings elicited: 96.34%
# ------------------------------------
# # of ratings elicited: 76619
# Percentage of ratings elicited: 97.18%
# ------------------------------------
# # of ratings elicited: 77164
# Percentage of ratings elicited: 97.87%
# ------------------------------------
# # of ratings elicited: 77631
# Percentage of ratings elicited: 98.46%
# ------------------------------------
# # of ratings elicited: 78028
# Percentage of ratings elicited: 98.96%
# ------------------------------------
# # of ratings elicited: 78373
# Percentage of ratings elicited: 99.40%
# ------------------------------------
# # of ratings elicited: 78649
# Percentage of ratings elicited: 99.75%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 5
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 17423
# Percentage of ratings elicited: 22.10%
# ------------------------------------
# # of ratings elicited: 26633
# Percentage of ratings elicited: 33.78%
# ------------------------------------
# # of ratings elicited: 33957
# Percentage of ratings elicited: 43.07%
# ------------------------------------
# # of ratings elicited: 40124
# Percentage of ratings elicited: 50.89%
# ------------------------------------
# # of ratings elicited: 45405
# Percentage of ratings elicited: 57.59%
# ------------------------------------
# # of ratings elicited: 50004
# Percentage of ratings elicited: 63.42%
# ------------------------------------
# # of ratings elicited: 53924
# Percentage of ratings elicited: 68.39%
# ------------------------------------
# # of ratings elicited: 57290
# Percentage of ratings elicited: 72.66%
# ------------------------------------
# # of ratings elicited: 60263
# Percentage of ratings elicited: 76.43%
# ------------------------------------
# # of ratings elicited: 62857
# Percentage of ratings elicited: 79.72%
# ------------------------------------
# # of ratings elicited: 65178
# Percentage of ratings elicited: 82.66%
# ------------------------------------
# # of ratings elicited: 67222
# Percentage of ratings elicited: 85.26%
# ------------------------------------
# # of ratings elicited: 68995
# Percentage of ratings elicited: 87.51%
# ------------------------------------
# # of ratings elicited: 70593
# Percentage of ratings elicited: 89.53%
# ------------------------------------
# # of ratings elicited: 72005
# Percentage of ratings elicited: 91.32%
# ------------------------------------
# # of ratings elicited: 73205
# Percentage of ratings elicited: 92.85%
# ------------------------------------
# # of ratings elicited: 74267
# Percentage of ratings elicited: 94.19%
# ------------------------------------
# # of ratings elicited: 75169
# Percentage of ratings elicited: 95.34%
# ------------------------------------
# # of ratings elicited: 75937
# Percentage of ratings elicited: 96.31%
# ------------------------------------
# # of ratings elicited: 76590
# Percentage of ratings elicited: 97.14%
# ------------------------------------
# # of ratings elicited: 77141
# Percentage of ratings elicited: 97.84%
# ------------------------------------
# # of ratings elicited: 77613
# Percentage of ratings elicited: 98.44%
# ------------------------------------
# # of ratings elicited: 78016
# Percentage of ratings elicited: 98.95%
# ------------------------------------
# # of ratings elicited: 78360
# Percentage of ratings elicited: 99.38%
# ------------------------------------
# # of ratings elicited: 78642
# Percentage of ratings elicited: 99.74%

# %%
len(pop_results_lst[0])
# Out:
# 26

# %%
df_lst = []
for iter in range(n_iters):
    results = pop_results_lst[iter]
    d = {}
    d['epoch'] = list(range(len(pop_results_lst[0])))
    d['percentage'] = [r['percentage'] for r in results]
    d['ndcg_pro'] = [r['ndcg'][0] for r in results]
    d['ndcg_unpro'] = [r['ndcg'][1] for r in results]
    d['precision_pro'] = [r['precision'][0] for r in results]
    d['precision_unpro'] = [r['precision'][1] for r in results]
    d['recall_pro'] = [r['recall'][0] for r in results]
    d['recall_unpro'] = [r['recall'][1] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

results_df = pd.concat(df_lst, axis=0)

# %%
results_df.to_csv('./outputs_nonpers_100k/pop_exp1.csv')

# %%
percentages = results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# precision
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# recall
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (Popularity)")
plt.show()
