# %%
import numpy as np
import pandas as pd
import tensorflow as tf 
import scipy.sparse as sp
from recommenders.evaluation.python_evaluation import (
    map_at_k,
    ndcg_at_k,
    precision_at_k,
    recall_at_k,
)

import LightGCN
from utils import get_top_k_scored_items, nCoreReduction, user_fixed_train_test_split

import matplotlib.pyplot as plt 

import importlib 

import ActiveLearner

# disable the SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Load data

# %%
data_path = "./data/ml-100k/u.data"
data_columns = ['user_id', 'item_id', 'rating', 'timestamp']

user_path = "./data/ml-100k/u.user"
user_columns = ['user_id', 'age', 'gender', 'occupation', 'zip_code']

# %%
data_df = pd.read_csv(data_path, sep='\t', names=data_columns, header=None)
user_df = pd.read_csv(user_path, sep='|', names=user_columns, header=None)

# %%
# shuffle data_df
data_df = data_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Convert to implicit feedback
#
# **Note**: For MovieLens 100k dataset, we are converting a rating in the range [1, 5] to an implicit feedback of 1 so that we still have a significant number of positive samples in the dataset. For MovieLens 1M, we could do [3, 5] instead.
#
# We might not need this.

# %%
# data_df['rating'] = (data_df['rating'] >= 1).astype(int)

# %% [markdown]
# ## Dimensionality reduction
#
# Only keep:
# - users that provided at least 5 ratings
# - items that received at least 5 ratings

# %%
ncore_data_df = nCoreReduction(data_df)

# %%
print(f"The original data frame shape: {data_df.shape}")
print(f"  - # users: {data_df['user_id'].nunique()}")
print(f"  - # items: {data_df['item_id'].nunique()}")
print('\n')

print(f"The filtered data frame shape: {ncore_data_df.shape}")
print(f"  - # users: {ncore_data_df['user_id'].nunique()}")
print(f"  - # items: {ncore_data_df['item_id'].nunique()}")
# Out:
# The original data frame shape: (100000, 4)
#   - # users: 943
#   - # items: 1682
#
#
# The filtered data frame shape: (99032, 4)
#   - # users: 943
#   - # items: 1298

# %% [markdown]
# ## Convert id to inner id

# %%
unique_users = ncore_data_df['user_id'].unique()
user_id_to_iid = {id: iid for iid, id in enumerate(unique_users)}
user_iid_to_id = {iid: id for iid, id in enumerate(unique_users)}

unique_items = ncore_data_df['item_id'].unique()
item_id_to_iid = {id: iid for iid, id in enumerate(unique_items)}
item_iid_to_id = {iid: id for iid, id in enumerate(unique_items)}

# %%
n_users = unique_users.shape[0]
n_items = unique_items.shape[0]

# %%
ncore_data_df['user_iid'] = ncore_data_df['user_id'].map(user_id_to_iid)
ncore_data_df['item_iid'] = ncore_data_df['item_id'].map(item_id_to_iid)

# apply to `user_df`` as well
user_df['user_iid'] = user_df['user_id'].map(user_id_to_iid)

# %%
iid_to_gender = dict(zip(user_df['user_iid'], user_df['gender']))

# %%
n_female, n_male = user_df['gender'].value_counts()[['F', 'M']]
print(f"Number of female users: {n_female}")
print(f"Number of male users: {n_male}")
# Out:
# Number of female users: 273
# Number of male users: 670

# %%
nratings_female = ncore_data_df[ncore_data_df['user_iid'].map(iid_to_gender) == 'F']
nratings_male = ncore_data_df[ncore_data_df['user_iid'].map(iid_to_gender) == 'M']
print(f"Number of ratings for female users: {nratings_female.shape[0]}")
print(f"Number of ratings for male users: {nratings_male.shape[0]}")
print(f"Percentage of ratings from female users: {100 * nratings_female.shape[0] / ncore_data_df.shape[0]:.2f}")
# Out:
# Number of ratings for female users: 25385
# Number of ratings for male users: 73647
# Percentage of ratings from female users: 25.63

# %% [markdown]
# ## Train test split (user-fixed)

# %%
train_df, test_df = user_fixed_train_test_split(ncore_data_df, test_size=0.3, random_state=42)

# %% [markdown]
# ## Personalized Active Learning

# %%
# hyper-parameters

# hyper-parameter for rec sys
hparams = {
    'epochs': 50,
    'learning_rate': 0.005,
    'embed_size': 64,
    'batch_size': 1024,
    'n_layers': 3,
    'decay': 0.0001,
    'eval_epoch': -1,
    'top_k': 10,
}


n_iters = 5   # number of repeated experiments
n_epochs = 26 # epoch of active learning process
q = 50        # active learning query list size

# %%
MaxRating_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.RatingBasedActiveLearner(
        strategy = 'MaxRating', 
        model = LightGCN.LightGCNRecommender,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=q,
        seed=iter,
        ratio=None,
    )
    MaxRating_results_lst.append([])
    for epoch in range(n_epochs):
        print('------------------------------------')
        print(f'Epoch: {epoch+1}')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        MaxRating_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 11020
# Percentage of ratings elicited: 15.99%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 21449
# Percentage of ratings elicited: 31.13%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 30508
# Percentage of ratings elicited: 44.28%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 37111
# Percentage of ratings elicited: 53.86%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 42491
# Percentage of ratings elicited: 61.67%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 46781
# Percentage of ratings elicited: 67.90%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 50172
# Percentage of ratings elicited: 72.82%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52796
# Percentage of ratings elicited: 76.63%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54980
# Percentage of ratings elicited: 79.80%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56987
# Percentage of ratings elicited: 82.71%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58753
# Percentage of ratings elicited: 85.27%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 60167
# Percentage of ratings elicited: 87.32%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61208
# Percentage of ratings elicited: 88.83%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62261
# Percentage of ratings elicited: 90.36%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 63188
# Percentage of ratings elicited: 91.71%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63994
# Percentage of ratings elicited: 92.88%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 64611
# Percentage of ratings elicited: 93.77%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 65206
# Percentage of ratings elicited: 94.64%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 65881
# Percentage of ratings elicited: 95.62%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 66519
# Percentage of ratings elicited: 96.54%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 67100
# Percentage of ratings elicited: 97.39%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 67505
# Percentage of ratings elicited: 97.97%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67977
# Percentage of ratings elicited: 98.66%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68402
# Percentage of ratings elicited: 99.28%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68776
# Percentage of ratings elicited: 99.82%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 2
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 10789
# Percentage of ratings elicited: 15.66%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 21378
# Percentage of ratings elicited: 31.03%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 30313
# Percentage of ratings elicited: 44.00%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 37026
# Percentage of ratings elicited: 53.74%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 42330
# Percentage of ratings elicited: 61.44%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 46606
# Percentage of ratings elicited: 67.64%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 49989
# Percentage of ratings elicited: 72.55%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52640
# Percentage of ratings elicited: 76.40%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54830
# Percentage of ratings elicited: 79.58%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56557
# Percentage of ratings elicited: 82.08%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58164
# Percentage of ratings elicited: 84.42%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59769
# Percentage of ratings elicited: 86.75%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61159
# Percentage of ratings elicited: 88.76%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62205
# Percentage of ratings elicited: 90.28%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 63048
# Percentage of ratings elicited: 91.51%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63768
# Percentage of ratings elicited: 92.55%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 64398
# Percentage of ratings elicited: 93.46%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 65020
# Percentage of ratings elicited: 94.37%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 65693
# Percentage of ratings elicited: 95.34%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 66366
# Percentage of ratings elicited: 96.32%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 67072
# Percentage of ratings elicited: 97.35%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 67610
# Percentage of ratings elicited: 98.13%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 68085
# Percentage of ratings elicited: 98.82%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68476
# Percentage of ratings elicited: 99.38%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68813
# Percentage of ratings elicited: 99.87%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 3
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 11125
# Percentage of ratings elicited: 16.15%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 21889
# Percentage of ratings elicited: 31.77%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 31082
# Percentage of ratings elicited: 45.11%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 37681
# Percentage of ratings elicited: 54.69%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 42684
# Percentage of ratings elicited: 61.95%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 46695
# Percentage of ratings elicited: 67.77%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 50044
# Percentage of ratings elicited: 72.63%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52769
# Percentage of ratings elicited: 76.59%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 55101
# Percentage of ratings elicited: 79.97%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 57002
# Percentage of ratings elicited: 82.73%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58694
# Percentage of ratings elicited: 85.19%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 60034
# Percentage of ratings elicited: 87.13%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61330
# Percentage of ratings elicited: 89.01%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62393
# Percentage of ratings elicited: 90.55%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 63254
# Percentage of ratings elicited: 91.80%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63997
# Percentage of ratings elicited: 92.88%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 64756
# Percentage of ratings elicited: 93.98%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 65412
# Percentage of ratings elicited: 94.94%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 66038
# Percentage of ratings elicited: 95.84%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 66710
# Percentage of ratings elicited: 96.82%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 67360
# Percentage of ratings elicited: 97.76%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 67761
# Percentage of ratings elicited: 98.35%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 68180
# Percentage of ratings elicited: 98.95%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68514
# Percentage of ratings elicited: 99.44%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68800
# Percentage of ratings elicited: 99.85%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 4
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 11072
# Percentage of ratings elicited: 16.07%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 21790
# Percentage of ratings elicited: 31.63%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 30411
# Percentage of ratings elicited: 44.14%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 36789
# Percentage of ratings elicited: 53.39%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 41944
# Percentage of ratings elicited: 60.88%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 46382
# Percentage of ratings elicited: 67.32%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 49900
# Percentage of ratings elicited: 72.42%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52579
# Percentage of ratings elicited: 76.31%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 54765
# Percentage of ratings elicited: 79.48%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56694
# Percentage of ratings elicited: 82.28%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58346
# Percentage of ratings elicited: 84.68%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59732
# Percentage of ratings elicited: 86.69%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61006
# Percentage of ratings elicited: 88.54%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62071
# Percentage of ratings elicited: 90.09%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 62957
# Percentage of ratings elicited: 91.37%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63809
# Percentage of ratings elicited: 92.61%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 64571
# Percentage of ratings elicited: 93.72%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 65214
# Percentage of ratings elicited: 94.65%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 65876
# Percentage of ratings elicited: 95.61%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 66479
# Percentage of ratings elicited: 96.48%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 67122
# Percentage of ratings elicited: 97.42%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 67639
# Percentage of ratings elicited: 98.17%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 68052
# Percentage of ratings elicited: 98.77%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68482
# Percentage of ratings elicited: 99.39%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68829
# Percentage of ratings elicited: 99.90%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 5
# ------------------------------------
# Epoch: 1
# # of ratings elicited: 3484
# Percentage of ratings elicited: 5.06%
# ------------------------------------
# Epoch: 2
# # of ratings elicited: 11060
# Percentage of ratings elicited: 16.05%
# ------------------------------------
# Epoch: 3
# # of ratings elicited: 21525
# Percentage of ratings elicited: 31.24%
# ------------------------------------
# Epoch: 4
# # of ratings elicited: 30345
# Percentage of ratings elicited: 44.04%
# ------------------------------------
# Epoch: 5
# # of ratings elicited: 37125
# Percentage of ratings elicited: 53.88%
# ------------------------------------
# Epoch: 6
# # of ratings elicited: 42506
# Percentage of ratings elicited: 61.69%
# ------------------------------------
# Epoch: 7
# # of ratings elicited: 46800
# Percentage of ratings elicited: 67.92%
# ------------------------------------
# Epoch: 8
# # of ratings elicited: 50205
# Percentage of ratings elicited: 72.87%
# ------------------------------------
# Epoch: 9
# # of ratings elicited: 52843
# Percentage of ratings elicited: 76.69%
# ------------------------------------
# Epoch: 10
# # of ratings elicited: 55047
# Percentage of ratings elicited: 79.89%
# ------------------------------------
# Epoch: 11
# # of ratings elicited: 56980
# Percentage of ratings elicited: 82.70%
# ------------------------------------
# Epoch: 12
# # of ratings elicited: 58552
# Percentage of ratings elicited: 84.98%
# ------------------------------------
# Epoch: 13
# # of ratings elicited: 59917
# Percentage of ratings elicited: 86.96%
# ------------------------------------
# Epoch: 14
# # of ratings elicited: 61153
# Percentage of ratings elicited: 88.75%
# ------------------------------------
# Epoch: 15
# # of ratings elicited: 62342
# Percentage of ratings elicited: 90.48%
# ------------------------------------
# Epoch: 16
# # of ratings elicited: 63163
# Percentage of ratings elicited: 91.67%
# ------------------------------------
# Epoch: 17
# # of ratings elicited: 63914
# Percentage of ratings elicited: 92.76%
# ------------------------------------
# Epoch: 18
# # of ratings elicited: 64668
# Percentage of ratings elicited: 93.86%
# ------------------------------------
# Epoch: 19
# # of ratings elicited: 65276
# Percentage of ratings elicited: 94.74%
# ------------------------------------
# Epoch: 20
# # of ratings elicited: 65951
# Percentage of ratings elicited: 95.72%
# ------------------------------------
# Epoch: 21
# # of ratings elicited: 66502
# Percentage of ratings elicited: 96.52%
# ------------------------------------
# Epoch: 22
# # of ratings elicited: 67073
# Percentage of ratings elicited: 97.35%
# ------------------------------------
# Epoch: 23
# # of ratings elicited: 67520
# Percentage of ratings elicited: 98.00%
# ------------------------------------
# Epoch: 24
# # of ratings elicited: 67998
# Percentage of ratings elicited: 98.69%
# ------------------------------------
# Epoch: 25
# # of ratings elicited: 68405
# Percentage of ratings elicited: 99.28%
# ------------------------------------
# Epoch: 26
# # of ratings elicited: 68784
# Percentage of ratings elicited: 99.83%

# %%
df_lst = []
for iter in range(n_iters):
    results = MaxRating_results_lst[iter]
    d = {}
    d['epoch'] = list(range(n_epochs))
    d['percentage'] = [r['percentage'] for r in results]
    d['map_pro'] = [r['map_pro'] for r in results]
    d['map_unpro'] = [r['map_unpro'] for r in results]
    d['ndcg_pro'] = [r['ndcg_pro'] for r in results]
    d['ndcg_unpro'] = [r['ndcg_unpro'] for r in results]
    d['precision_pro'] = [r['precision_pro'] for r in results]
    d['precision_unpro'] = [r['precision_unpro'] for r in results]
    d['recall_pro'] = [r['recall_pro'] for r in results]
    d['recall_unpro'] = [r['recall_unpro'] for r in results]
    d['rmse_pro'] = [r['rmse_pro'] for r in results]
    d['rmse_unpro'] = [r['rmse_unpro'] for r in results]
    d['rocauc_pro'] = [r['rocauc_pro'] for r in results]
    d['rocauc_unpro'] = [r['rocauc_unpro'] for r in results]
    d['agg_item_coverage_pro'] = [r['agg_item_coverage_pro'] for r in results]
    d['agg_item_coverage_unpro'] = [r['agg_item_coverage_unpro'] for r in results]
    d['avg_item_coverage_pro'] = [r['avg_item_coverage_pro'] for r in results]
    d['avg_item_coverage_unpro'] = [r['avg_item_coverage_unpro'] for r in results]
    d['count_pro'] = [r['count_pro'] for r in results]
    d['count_unpro'] = [r['count_unpro'] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

MaxRating_results_df = pd.concat(df_lst, axis=0, ignore_index=True)

# %%
MaxRating_results_df.to_csv('./outputs_pers_100k/MaxRating_exp1.csv')

# %% [markdown]
# ### Plots

# %%
MaxRating_results_df = pd.read_csv('./outputs_pers_100k/MaxRating_exp1.csv')

# %%
percentages = MaxRating_results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# precision
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# recall
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (MaxRating)")
plt.show()

# %%
# RMSE
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('RMSE')

plt.legend()
plt.title("RMSE For Female and Male Users (MaxRating)")
plt.show()

# %%
# rocauc
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('AUCROC')

plt.legend()
plt.title("AUCROC For Female and Male Users (MaxRating)")
plt.show()

# %%
# aggregate item coverage
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['agg_item_coverage_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['agg_item_coverage_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Item Coverage')

plt.legend()
plt.title("Aggregate Item Coverage For Female and Male Users (MaxRating)")
plt.show()

# %%
# average individual item coverage
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['avg_item_coverage_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['avg_item_coverage_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='tab:red', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='tab:red',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='tab:blue', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='tab:blue',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Item Coverage')

plt.legend()
plt.title("Average Individual Item Coverage For Female and Male Users (MaxRating)")
plt.show()

# %%
# count
pro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = MaxRating_results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(np.arange(pro_df_grouped.shape[0]), pro_df_grouped['mean'], color='tab:red', label="Female")

plt.plot(np.arange(unpro_df_grouped.shape[0]), unpro_df_grouped['mean'], color='tab:blue', label="Male")

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Rating count')

plt.legend()
plt.title("Rating Count For Female and Male Users (MaxRating)")
plt.show()

# %%
# response rate
count_df = MaxRating_results_df[['epoch', 'count_pro', 'count_unpro']]
mean_count_df = count_df.groupby('epoch').agg('mean')
collected_count_df = mean_count_df.diff()
collected_count_df = collected_count_df.iloc[1:]

collected_count_df['rate_pro'] = collected_count_df['count_pro'] / (q * n_female)
collected_count_df['rate_unpro'] = collected_count_df['count_unpro'] / (q * n_male)

x = np.arange(1, collected_count_df.shape[0]+1)
width = 0.3
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for col, label, c in zip(['rate_pro', 'rate_unpro'], ['Female', 'Male'], ['tab:red', 'tab:blue']):
    offset = width * multiplier
    rects = ax.bar(x + offset, collected_count_df[col], width, label=label, color=c)
    multiplier += 1

ax.set_ylabel('Response Rate')
ax.set_xlabel('# Epoch')
ax.set_xticks(x + width, x)
ax.legend()

plt.title("Response Rate For Female and Male Users (MaxRating)")
plt.show()

# %% [markdown]
# ## Nonpersonalized Active Learning

# %%
importlib.reload(ActiveLearner)
importlib.reload(LightGCN)
# Out:
# <module 'LightGCN' from '/Users/sipei/Tufts/Research/DeepALDataMinimization/LightGCN.py'>

# %%
hparams = {
    'epochs': 50,
    'learning_rate': 0.005,
    'embed_size': 64,
    'batch_size': 1024,
    'n_layers': 3,
    'decay': 0.0001,
    'eval_epoch': -1,
    'top_k': 10,
}

n_iters = 5
n_epochs = 30
q = 50

# %%
pop_results_lst = []
for iter in range(n_iters):
    print('------------------------------------')
    print('------------------------------------')
    print(f'Starting the Active Learning process, iteration {iter+1}')
    al = ActiveLearner.NonpersonalizedActiveLearner(
        strategy = 'pop', 
        model = LightGCN.LightGCNRecommender,
        model_hparams=hparams,
        tr_df=train_df[['user_iid', 'item_iid', 'rating']],
        te_df=test_df[['user_iid', 'item_iid', 'rating']],
        n_users=n_users,
        n_items=n_items,
        iid_to_gender=iid_to_gender,
        q=q,
        seed=iter,
        ratio=None,
    )
    pop_results_lst.append([])
    while al.i_indx < al.n_items:
        print('------------------------------------')
        print(f'# of ratings elicited: {al.kn_df.shape[0]}')
        print(f'Percentage of ratings elicited: {100*(al.kn_df.shape[0]/train_df.shape[0]):.2f}%')
        results = al.run_epoch()
        pop_results_lst[-1].append(results)
# Out:
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 1
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 18135
# Percentage of ratings elicited: 23.00%
# ------------------------------------
# # of ratings elicited: 27141
# Percentage of ratings elicited: 34.42%
# ------------------------------------
# # of ratings elicited: 34343
# Percentage of ratings elicited: 43.56%
# ------------------------------------
# # of ratings elicited: 40476
# Percentage of ratings elicited: 51.34%
# ------------------------------------
# # of ratings elicited: 45699
# Percentage of ratings elicited: 57.96%
# ------------------------------------
# # of ratings elicited: 50275
# Percentage of ratings elicited: 63.76%
# ------------------------------------
# # of ratings elicited: 54178
# Percentage of ratings elicited: 68.71%
# ------------------------------------
# # of ratings elicited: 57520
# Percentage of ratings elicited: 72.95%
# ------------------------------------
# # of ratings elicited: 60454
# Percentage of ratings elicited: 76.67%
# ------------------------------------
# # of ratings elicited: 63033
# Percentage of ratings elicited: 79.94%
# ------------------------------------
# # of ratings elicited: 65327
# Percentage of ratings elicited: 82.85%
# ------------------------------------
# # of ratings elicited: 67373
# Percentage of ratings elicited: 85.45%
# ------------------------------------
# # of ratings elicited: 69121
# Percentage of ratings elicited: 87.67%
# ------------------------------------
# # of ratings elicited: 70705
# Percentage of ratings elicited: 89.67%
# ------------------------------------
# # of ratings elicited: 72114
# Percentage of ratings elicited: 91.46%
# ------------------------------------
# # of ratings elicited: 73317
# Percentage of ratings elicited: 92.99%
# ------------------------------------
# # of ratings elicited: 74367
# Percentage of ratings elicited: 94.32%
# ------------------------------------
# # of ratings elicited: 75250
# Percentage of ratings elicited: 95.44%
# ------------------------------------
# # of ratings elicited: 76004
# Percentage of ratings elicited: 96.40%
# ------------------------------------
# # of ratings elicited: 76646
# Percentage of ratings elicited: 97.21%
# ------------------------------------
# # of ratings elicited: 77194
# Percentage of ratings elicited: 97.90%
# ------------------------------------
# # of ratings elicited: 77654
# Percentage of ratings elicited: 98.49%
# ------------------------------------
# # of ratings elicited: 78048
# Percentage of ratings elicited: 98.99%
# ------------------------------------
# # of ratings elicited: 78385
# Percentage of ratings elicited: 99.42%
# ------------------------------------
# # of ratings elicited: 78663
# Percentage of ratings elicited: 99.77%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 2
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 18135
# Percentage of ratings elicited: 23.00%
# ------------------------------------
# # of ratings elicited: 27119
# Percentage of ratings elicited: 34.39%
# ------------------------------------
# # of ratings elicited: 34354
# Percentage of ratings elicited: 43.57%
# ------------------------------------
# # of ratings elicited: 40518
# Percentage of ratings elicited: 51.39%
# ------------------------------------
# # of ratings elicited: 45725
# Percentage of ratings elicited: 57.99%
# ------------------------------------
# # of ratings elicited: 50309
# Percentage of ratings elicited: 63.81%
# ------------------------------------
# # of ratings elicited: 54173
# Percentage of ratings elicited: 68.71%
# ------------------------------------
# # of ratings elicited: 57531
# Percentage of ratings elicited: 72.97%
# ------------------------------------
# # of ratings elicited: 60442
# Percentage of ratings elicited: 76.66%
# ------------------------------------
# # of ratings elicited: 63018
# Percentage of ratings elicited: 79.93%
# ------------------------------------
# # of ratings elicited: 65320
# Percentage of ratings elicited: 82.85%
# ------------------------------------
# # of ratings elicited: 67365
# Percentage of ratings elicited: 85.44%
# ------------------------------------
# # of ratings elicited: 69114
# Percentage of ratings elicited: 87.66%
# ------------------------------------
# # of ratings elicited: 70703
# Percentage of ratings elicited: 89.67%
# ------------------------------------
# # of ratings elicited: 72099
# Percentage of ratings elicited: 91.44%
# ------------------------------------
# # of ratings elicited: 73293
# Percentage of ratings elicited: 92.96%
# ------------------------------------
# # of ratings elicited: 74336
# Percentage of ratings elicited: 94.28%
# ------------------------------------
# # of ratings elicited: 75242
# Percentage of ratings elicited: 95.43%
# ------------------------------------
# # of ratings elicited: 75997
# Percentage of ratings elicited: 96.39%
# ------------------------------------
# # of ratings elicited: 76658
# Percentage of ratings elicited: 97.22%
# ------------------------------------
# # of ratings elicited: 77190
# Percentage of ratings elicited: 97.90%
# ------------------------------------
# # of ratings elicited: 77647
# Percentage of ratings elicited: 98.48%
# ------------------------------------
# # of ratings elicited: 78041
# Percentage of ratings elicited: 98.98%
# ------------------------------------
# # of ratings elicited: 78381
# Percentage of ratings elicited: 99.41%
# ------------------------------------
# # of ratings elicited: 78658
# Percentage of ratings elicited: 99.76%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 3
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 18135
# Percentage of ratings elicited: 23.00%
# ------------------------------------
# # of ratings elicited: 27133
# Percentage of ratings elicited: 34.41%
# ------------------------------------
# # of ratings elicited: 34413
# Percentage of ratings elicited: 43.65%
# ------------------------------------
# # of ratings elicited: 40565
# Percentage of ratings elicited: 51.45%
# ------------------------------------
# # of ratings elicited: 45776
# Percentage of ratings elicited: 58.06%
# ------------------------------------
# # of ratings elicited: 50370
# Percentage of ratings elicited: 63.88%
# ------------------------------------
# # of ratings elicited: 54243
# Percentage of ratings elicited: 68.80%
# ------------------------------------
# # of ratings elicited: 57580
# Percentage of ratings elicited: 73.03%
# ------------------------------------
# # of ratings elicited: 60508
# Percentage of ratings elicited: 76.74%
# ------------------------------------
# # of ratings elicited: 63067
# Percentage of ratings elicited: 79.99%
# ------------------------------------
# # of ratings elicited: 65364
# Percentage of ratings elicited: 82.90%
# ------------------------------------
# # of ratings elicited: 67397
# Percentage of ratings elicited: 85.48%
# ------------------------------------
# # of ratings elicited: 69139
# Percentage of ratings elicited: 87.69%
# ------------------------------------
# # of ratings elicited: 70704
# Percentage of ratings elicited: 89.67%
# ------------------------------------
# # of ratings elicited: 72107
# Percentage of ratings elicited: 91.45%
# ------------------------------------
# # of ratings elicited: 73308
# Percentage of ratings elicited: 92.98%
# ------------------------------------
# # of ratings elicited: 74345
# Percentage of ratings elicited: 94.29%
# ------------------------------------
# # of ratings elicited: 75243
# Percentage of ratings elicited: 95.43%
# ------------------------------------
# # of ratings elicited: 76005
# Percentage of ratings elicited: 96.40%
# ------------------------------------
# # of ratings elicited: 76651
# Percentage of ratings elicited: 97.22%
# ------------------------------------
# # of ratings elicited: 77190
# Percentage of ratings elicited: 97.90%
# ------------------------------------
# # of ratings elicited: 77646
# Percentage of ratings elicited: 98.48%
# ------------------------------------
# # of ratings elicited: 78043
# Percentage of ratings elicited: 98.98%
# ------------------------------------
# # of ratings elicited: 78378
# Percentage of ratings elicited: 99.41%
# ------------------------------------
# # of ratings elicited: 78658
# Percentage of ratings elicited: 99.76%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 4
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 18135
# Percentage of ratings elicited: 23.00%
# ------------------------------------
# # of ratings elicited: 27109
# Percentage of ratings elicited: 34.38%
# ------------------------------------
# # of ratings elicited: 34364
# Percentage of ratings elicited: 43.58%
# ------------------------------------
# # of ratings elicited: 40496
# Percentage of ratings elicited: 51.36%
# ------------------------------------
# # of ratings elicited: 45748
# Percentage of ratings elicited: 58.02%
# ------------------------------------
# # of ratings elicited: 50317
# Percentage of ratings elicited: 63.82%
# ------------------------------------
# # of ratings elicited: 54196
# Percentage of ratings elicited: 68.74%
# ------------------------------------
# # of ratings elicited: 57547
# Percentage of ratings elicited: 72.99%
# ------------------------------------
# # of ratings elicited: 60493
# Percentage of ratings elicited: 76.72%
# ------------------------------------
# # of ratings elicited: 63050
# Percentage of ratings elicited: 79.97%
# ------------------------------------
# # of ratings elicited: 65365
# Percentage of ratings elicited: 82.90%
# ------------------------------------
# # of ratings elicited: 67397
# Percentage of ratings elicited: 85.48%
# ------------------------------------
# # of ratings elicited: 69150
# Percentage of ratings elicited: 87.70%
# ------------------------------------
# # of ratings elicited: 70711
# Percentage of ratings elicited: 89.68%
# ------------------------------------
# # of ratings elicited: 72111
# Percentage of ratings elicited: 91.46%
# ------------------------------------
# # of ratings elicited: 73308
# Percentage of ratings elicited: 92.98%
# ------------------------------------
# # of ratings elicited: 74354
# Percentage of ratings elicited: 94.30%
# ------------------------------------
# # of ratings elicited: 75244
# Percentage of ratings elicited: 95.43%
# ------------------------------------
# # of ratings elicited: 76000
# Percentage of ratings elicited: 96.39%
# ------------------------------------
# # of ratings elicited: 76647
# Percentage of ratings elicited: 97.21%
# ------------------------------------
# # of ratings elicited: 77196
# Percentage of ratings elicited: 97.91%
# ------------------------------------
# # of ratings elicited: 77654
# Percentage of ratings elicited: 98.49%
# ------------------------------------
# # of ratings elicited: 78052
# Percentage of ratings elicited: 98.99%
# ------------------------------------
# # of ratings elicited: 78386
# Percentage of ratings elicited: 99.42%
# ------------------------------------
# # of ratings elicited: 78672
# Percentage of ratings elicited: 99.78%
# ------------------------------------
# ------------------------------------
# Starting the Active Learning process, iteration 5
# ------------------------------------
# # of ratings elicited: 3939
# Percentage of ratings elicited: 5.00%
# ------------------------------------
# # of ratings elicited: 18135
# Percentage of ratings elicited: 23.00%
# ------------------------------------
# # of ratings elicited: 27113
# Percentage of ratings elicited: 34.39%
# ------------------------------------
# # of ratings elicited: 34363
# Percentage of ratings elicited: 43.58%
# ------------------------------------
# # of ratings elicited: 40489
# Percentage of ratings elicited: 51.35%
# ------------------------------------
# # of ratings elicited: 45663
# Percentage of ratings elicited: 57.91%
# ------------------------------------
# # of ratings elicited: 50254
# Percentage of ratings elicited: 63.74%
# ------------------------------------
# # of ratings elicited: 54113
# Percentage of ratings elicited: 68.63%
# ------------------------------------
# # of ratings elicited: 57481
# Percentage of ratings elicited: 72.90%
# ------------------------------------
# # of ratings elicited: 60407
# Percentage of ratings elicited: 76.61%
# ------------------------------------
# # of ratings elicited: 62992
# Percentage of ratings elicited: 79.89%
# ------------------------------------
# # of ratings elicited: 65296
# Percentage of ratings elicited: 82.81%
# ------------------------------------
# # of ratings elicited: 67328
# Percentage of ratings elicited: 85.39%
# ------------------------------------
# # of ratings elicited: 69076
# Percentage of ratings elicited: 87.61%
# ------------------------------------
# # of ratings elicited: 70667
# Percentage of ratings elicited: 89.63%
# ------------------------------------
# # of ratings elicited: 72077
# Percentage of ratings elicited: 91.41%
# ------------------------------------
# # of ratings elicited: 73280
# Percentage of ratings elicited: 92.94%
# ------------------------------------
# # of ratings elicited: 74321
# Percentage of ratings elicited: 94.26%
# ------------------------------------
# # of ratings elicited: 75223
# Percentage of ratings elicited: 95.40%
# ------------------------------------
# # of ratings elicited: 75979
# Percentage of ratings elicited: 96.36%
# ------------------------------------
# # of ratings elicited: 76623
# Percentage of ratings elicited: 97.18%
# ------------------------------------
# # of ratings elicited: 77167
# Percentage of ratings elicited: 97.87%
# ------------------------------------
# # of ratings elicited: 77631
# Percentage of ratings elicited: 98.46%
# ------------------------------------
# # of ratings elicited: 78034
# Percentage of ratings elicited: 98.97%
# ------------------------------------
# # of ratings elicited: 78374
# Percentage of ratings elicited: 99.40%
# ------------------------------------
# # of ratings elicited: 78659
# Percentage of ratings elicited: 99.76%

# %%
df_lst = []
for iter in range(n_iters):
    results = pop_results_lst[iter]
    d = {}
    d['epoch'] = list(range(len(pop_results_lst[0])))
    d['percentage'] = [r['percentage'] for r in results]
    d['map_pro'] = [r['map_pro'] for r in results]
    d['map_unpro'] = [r['map_unpro'] for r in results]
    d['ndcg_pro'] = [r['ndcg_pro'] for r in results]
    d['ndcg_unpro'] = [r['ndcg_unpro'] for r in results]
    d['precision_pro'] = [r['precision_pro'] for r in results]
    d['precision_unpro'] = [r['precision_unpro'] for r in results]
    d['recall_pro'] = [r['recall_pro'] for r in results]
    d['recall_unpro'] = [r['recall_unpro'] for r in results]
    d['rmse_pro'] = [r['rmse_pro'] for r in results]
    d['rmse_unpro'] = [r['rmse_unpro'] for r in results]
    d['rocauc_pro'] = [r['rocauc_pro'] for r in results]
    d['rocauc_unpro'] = [r['rocauc_unpro'] for r in results]
    d['count_pro'] = [r['count_pro'] for r in results]
    d['count_unpro'] = [r['count_unpro'] for r in results]
    df = pd.DataFrame.from_dict(d)
    df_lst.append(df)

results_df = pd.concat(df_lst, axis=0)

# %%
results_df.to_csv('./outputs_nonpers_100k/pop_exp1.csv')

# %%
percentages = results_df.groupby('epoch')['percentage'].agg('mean')

# %%
# ndcg
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['ndcg_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('NDCG@10')

plt.legend()
plt.title("NDCG@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# precision
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['precision_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Precision@10')

plt.legend()
plt.title("Precision@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# recall
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['recall_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Recall@10')

plt.legend()
plt.title("Recall@10 For Female and Male Users (Popularity)")
plt.show()

# %%
# rmse
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rmse_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('RMSE')

plt.legend()
plt.title("RMSE For Female and Male Users (Popularity)")
plt.show()

# %%
# rocauc
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['rocauc_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(percentages, pro_df_grouped['mean'], color='r', label="Female")
plt.fill_between(
    percentages,
    pro_df_grouped['ci_lower'],
    pro_df_grouped['ci_upper'],
    color='r',
    alpha=.1
)

plt.plot(percentages, unpro_df_grouped['mean'], color='b', label="Male")
plt.fill_between(
    percentages,
    unpro_df_grouped['ci_lower'],
    unpro_df_grouped['ci_upper'],
    color='b',
    alpha=.1
)

plt.xlabel('Percentage of ratings collected')
plt.ylabel('AUCROC')

plt.legend()
plt.title("AUCROC For Female and Male Users (Popularity)")
plt.show()

# %%
# count
pro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_pro']
pro_df_grouped['ci'] = 1.95 * pro_df_grouped['std'] / np.sqrt(pro_df_grouped['count'])
pro_df_grouped['ci_lower'] = pro_df_grouped['mean'] - pro_df_grouped['ci']
pro_df_grouped['ci_upper'] = pro_df_grouped['mean'] + pro_df_grouped['ci']

unpro_df_grouped = results_df.groupby('epoch').agg(['mean', 'std', 'count'])['count_unpro']
unpro_df_grouped['ci'] = 1.95 * unpro_df_grouped['std'] / np.sqrt(unpro_df_grouped['count'])
unpro_df_grouped['ci_lower'] = unpro_df_grouped['mean'] - unpro_df_grouped['ci']
unpro_df_grouped['ci_upper'] = unpro_df_grouped['mean'] + unpro_df_grouped['ci']

plt.plot(np.arange(pro_df_grouped.shape[0]), pro_df_grouped['mean'], color='tab:red', label="Female")

plt.plot(np.arange(unpro_df_grouped.shape[0]), unpro_df_grouped['mean'], color='tab:blue', label="Male")

plt.xlabel('Percentage of ratings collected')
plt.ylabel('Rating count')

plt.legend()
plt.title("Rating count For Female and Male Users (Popularity)")
plt.show()

# %%
# response rate
count_df = results_df[['epoch', 'count_pro', 'count_unpro']]
mean_count_df = count_df.groupby('epoch').agg('mean')
collected_count_df = mean_count_df.diff()
collected_count_df = collected_count_df.iloc[1:]

collected_count_df['rate_pro'] = collected_count_df['count_pro'] / (q * n_female)
collected_count_df['rate_unpro'] = collected_count_df['count_unpro'] / (q * n_male)

x = np.arange(1, collected_count_df.shape[0]+1)
width = 0.3
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for col, label, c in zip(['rate_pro', 'rate_unpro'], ['Female', 'Male'], ['tab:red', 'tab:blue']):
    offset = width * multiplier
    rects = ax.bar(x + offset, collected_count_df[col], width, label=label, color=c)
    multiplier += 1

ax.set_ylabel('Response Rate')
ax.set_xlabel('# Epoch')
ax.set_xticks(x + width, x)
ax.legend()

plt.title("Response Rate For Female and Male Users (Popularity)")
plt.show()
